# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
# Your code here
heroes_df = pd.read_csv('heroes_information.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
# Your code here
heroes_df = heroes_df.drop(['Unnamed: 0'], axis=1)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == ['name', 'Gender', 'Eye color', 'Race',
 'Hair color', 'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight']

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# Your code here
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
# Replace None with appropriate text
"""
The data types line up as expected, with the categorical features having 
string object values and the numeric features (w + h) having floats
There are missing values in the publisher and weight columns
There are placeholders in the skin colour column, and some odd results in
the weight column (-99). |Two of the sample also share exactly the same height 
and weight, which could be worth investigating, to make sure they aren't
placeholders, or if it is an default within a publishing house
"""

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df = pd.read_csv('super_hero_powers.csv', index_col=0)
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 167 entries, Agility to Omniscient
# Columns: 667 entries, 3-D Man to Zoom
# dtypes: bool(667)
# memory usage: 110.1+ KB

# %%
powers_df.shape
# Out:
# (167, 667)

# %%
"""
The data types are what we expect, with boolean valules in all the columns
There are no missing data
"""

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == '3-D Man'

# The last column should be 'Zoom'
assert powers_df.columns[-1] == 'Zoom'

# The first index should be 'Agility'
assert powers_df.index[0] == 'Agility'

# The last index should be 'Omniscient'
assert powers_df.index[-1] == 'Omniscient'

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(5, random_state=1)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(5, random_state=1)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
remove the rows as we won't be losing much information given only 2% of rows
are missing, and it appears those rows are also missing a lot of other values,
as there are a lot of placeholders. This would require imputing a lot of 
information
"""

# %% [markdown]
# Now, implement your chosen strategy using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Your code here
heroes_df.dropna(subset=['Publisher'], inplace=True)

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# George Lucas          14
# Image Comics          14
# Marvel                 9
# HarperCollins          6
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# IDW Publishing         4
# Shueisha               4
# ABC Studios            4
# Icon Comics            4
# Wildstorm              3
#  DC Comics             3
# Sony Pictures          2
# J. R. R. Tolkien       1
# Microsoft              1
# J. K. Rowling          1
# Titan Books            1
# Rebellion              1
# Universal Studios      1
# South Park             1
# Hanna-Barbera          1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
There is a Marvel column that is meant to be Marvel Comics, and ' DC Domics'
with a superfluous white space
"""

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
# Your code here
heroes_df['Publisher'].replace(to_replace='Marvel', value='Marvel Comics', inplace=True)
heroes_df.Publisher.value_counts()
# Out:
# Marvel Comics        388
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# HarperCollins          6
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# ABC Studios            4
# Shueisha               4
# Icon Comics            4
# IDW Publishing         4
# Wildstorm              3
#  DC Comics             3
# Sony Pictures          2
# J. R. R. Tolkien       1
# South Park             1
# Rebellion              1
# Titan Books            1
# Microsoft              1
# Universal Studios      1
# J. K. Rowling          1
# Hanna-Barbera          1
# Name: Publisher, dtype: int64

# %% [markdown]
# Check your work below:

# %%
heroes_df["Publisher"] = heroes_df["Publisher"].str.strip()

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [719 rows x 10 columns]

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
Name is the shared key. For the task in hand we need only the number of 
superpowers, so we need to make the names the index in powers frame, add a new
column with sum and then do an inner join, so that only the hero names that appear
in both frames are included

--- ADDS - Looking at Q3, we need add the new column to a fully joined frame,
as we will need to have publisher and all powers in the same table, not just the total.
Will sum up the powers in that frame rather than creating a new column in
existing frame and only joining that
"""

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
# Your code here (create more cells as needed)
# transpose powers dataframe. 
powers_df_transposed = powers_df.T
powers_df_transposed
# Out:
#                  Agility  Accelerated Healing  Lantern Power Ring  \
# 3-D Man             True                False               False
# A-Bomb             False                 True               False
# Abe Sapien          True                 True               False
# Abin Sur           False                False                True
# Abomination        False                 True               False
# ...                  ...                  ...                 ...
# Yellowjacket II    False                False               False
# Ymir               False                False               False
# Yoda                True                False               False
# Zatanna            False                False               False
# Zoom               False                False               False
#
#                  Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 3-D Man                          False            False       False    False
# A-Bomb                           False            False        True    False
# Abe Sapien                       False             True        True    False
# Abin Sur                         False            False       False    False
# Abomination                      False            False       False    False
# ...                                ...              ...         ...      ...
# Yellowjacket II                  False            False       False    False
# Ymir                             False             True        True    False
# Yoda                             False            False       False     True
# Zatanna                          False            False       False    False
# Zoom                             False            False       False    False
#
#                  Energy Absorption  Flight  Danger Sense  ...  Web Creation  \
# 3-D Man                      False   False         False  ...         False
# A-Bomb                       False   False         False  ...         False
# Abe Sapien                   False   False         False  ...         False
# Abin Sur                     False   False         False  ...         False
# Abomination                  False   False         False  ...         False
# ...                            ...     ...           ...  ...           ...
# Yellowjacket II              False    True         False  ...         False
# Ymir                         False   False         False  ...         False
# Yoda                         False   False          True  ...         False
# Zatanna                      False   False         False  ...         False
# Zoom                         False   False         False  ...         False
#
#                  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 3-D Man                    False       False             False        False
# A-Bomb                     False       False             False        False
# Abe Sapien                 False       False             False        False
# Abin Sur                   False       False             False        False
# Abomination                False       False             False        False
# ...                          ...         ...               ...          ...
# Yellowjacket II            False       False             False        False
# Ymir                       False       False             False        False
# Yoda                       False       False             False        False
# Zatanna                    False       False             False        False
# Zoom                       False       False             False        False
#
#                  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 3-D Man                  False                  False          False
# A-Bomb                   False                  False          False
# Abe Sapien               False                  False          False
# Abin Sur                 False                  False          False
# Abomination              False                  False          False
# ...                        ...                    ...            ...
# Yellowjacket II          False                  False          False
# Ymir                     False                  False          False
# Yoda                     False                  False          False
# Zatanna                  False                  False          False
# Zoom                     False                  False          False
#
#                  Omnipresent  Omniscient
# 3-D Man                False       False
# A-Bomb                 False       False
# Abe Sapien             False       False
# Abin Sur               False       False
# Abomination            False       False
# ...                      ...         ...
# Yellowjacket II        False       False
# Ymir                   False       False
# Yoda                   False       False
# Zatanna                False       False
# Zoom                   False       False
#
# [667 rows x 167 columns]

# %%
powers_df_transposed.columns
# Out:
# Index(['Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight', 'Danger Sense',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=167)

# %%
#join the tables, one method using join by reseting index, other with merge
#on name

#METHOD 1
#make heroes_df with name index
df_heroes_name_index = heroes_df.set_index('name')
df_heroes_name_index
# Out:
#                  Gender Eye color               Race        Hair color  \
# name
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment  Weight
# name
# A-Bomb            203.0      Marvel Comics          -      good   441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good    65.0
# Abin Sur          185.0          DC Comics        red      good    90.0
# Abomination       203.0      Marvel Comics          -       bad   441.0
# Abraxas           -99.0      Marvel Comics          -       bad   -99.0
# ...                 ...                ...        ...       ...     ...
# Yellowjacket II   165.0      Marvel Comics          -      good    52.0
# Ymir              304.8      Marvel Comics      white      good   -99.0
# Yoda               66.0       George Lucas      green      good    17.0
# Zatanna           170.0          DC Comics          -      good    57.0
# Zoom              185.0          DC Comics          -       bad    81.0
#
# [719 rows x 9 columns]

# %%
#join with join
heroes_and_powers_j_df = df_heroes_name_index.join(powers_df_transposed, how='inner')
heroes_and_powers_j_df
# Out:
#                  Gender Eye color               Race        Hair color  \
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment  Weight  \
# A-Bomb            203.0      Marvel Comics          -      good   441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good    65.0
# Abin Sur          185.0          DC Comics        red      good    90.0
# Abomination       203.0      Marvel Comics          -       bad   441.0
# Abraxas           -99.0      Marvel Comics          -       bad   -99.0
# ...                 ...                ...        ...       ...     ...
# Yellowjacket II   165.0      Marvel Comics          -      good    52.0
# Ymir              304.8      Marvel Comics      white      good   -99.0
# Yoda               66.0       George Lucas      green      good    17.0
# Zatanna           170.0          DC Comics          -      good    57.0
# Zoom              185.0          DC Comics          -       bad    81.0
#
#                  Agility  ...  Web Creation  Reality Warping  Odin Force  \
# A-Bomb             False  ...         False            False       False
# Abe Sapien          True  ...         False            False       False
# Abin Sur           False  ...         False            False       False
# Abomination        False  ...         False            False       False
# Abraxas            False  ...         False            False       False
# ...                  ...  ...           ...              ...         ...
# Yellowjacket II    False  ...         False            False       False
# Ymir               False  ...         False            False       False
# Yoda                True  ...         False            False       False
# Zatanna            False  ...         False            False       False
# Zoom               False  ...         False            False       False
#
#                  Symbiote Costume  Speed Force  Phoenix Force  \
# A-Bomb                      False        False          False
# Abe Sapien                  False        False          False
# Abin Sur                    False        False          False
# Abomination                 False        False          False
# Abraxas                     False        False          False
# ...                           ...          ...            ...
# Yellowjacket II             False        False          False
# Ymir                        False        False          False
# Yoda                        False        False          False
# Zatanna                     False        False          False
# Zoom                        False        False          False
#
#                  Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient
# A-Bomb                           False          False        False       False
# Abe Sapien                       False          False        False       False
# Abin Sur                         False          False        False       False
# Abomination                      False          False        False       False
# Abraxas                          False          False        False       False
# ...                                ...            ...          ...         ...
# Yellowjacket II                  False          False        False       False
# Ymir                             False          False        False       False
# Yoda                             False          False        False       False
# Zatanna                          False          False        False       False
# Zoom                             False          False        False       False
#
# [647 rows x 176 columns]

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a dataframe with the specified name
assert type(heroes_and_powers_j_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_j_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_j_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you mgith need to 
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_j_df.columns for attribute in heroes_df.columns]

# %%
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [719 rows x 10 columns]

# %%
#METHOD 2 using merge
heroes_and_powers_m_df = heroes_df.merge(powers_df_transposed, left_on='name', right_index=True)
heroes_and_powers_m_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 729   165.0      Marvel Comics          -      good    52.0  ...
# 730   304.8      Marvel Comics      white      good   -99.0  ...
# 731    66.0       George Lucas      green      good    17.0  ...
# 732   170.0          DC Comics          -      good    57.0  ...
# 733   185.0          DC Comics          -       bad    81.0  ...
#
#      Web Creation  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0           False            False       False             False        False
# 1           False            False       False             False        False
# 2           False            False       False             False        False
# 3           False            False       False             False        False
# 4           False            False       False             False        False
# ..            ...              ...         ...               ...          ...
# 729         False            False       False             False        False
# 730         False            False       False             False        False
# 731         False            False       False             False        False
# 732         False            False       False             False        False
# 733         False            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 729       False
# 730       False
# 731       False
# 732       False
# 733       False
#
# [647 rows x 177 columns]

# %%
# Run this cell without changes

# Confirms you have created a dataframe with the specified name
assert type(heroes_and_powers_m_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_m_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_m_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you mgith need to 
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_m_df.columns for attribute in heroes_df.columns]

# %%
""""
both give correct answers, the merge method is much quicker, and if we want
to have name as the index, easier to merge and change later

# %%
heroes_and_powers_df = heroes_and_powers_m_df

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum([heroes_and_powers_df[power_name] for power_name in powers_df.index])
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 729   165.0      Marvel Comics          -      good    52.0  ...
# 730   304.8      Marvel Comics      white      good   -99.0  ...
# 731    66.0       George Lucas      green      good    17.0  ...
# 732   170.0          DC Comics          -      good    57.0  ...
# 733   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 729            False       False             False        False
# 730            False       False             False        False
# 731            False       False             False        False
# 732            False       False             False        False
# 733            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 729       False            3
# 730       False            6
# 731       False           19
# 732       False            8
# 733       False            4
#
# [647 rows x 178 columns]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"],
    y=heroes_and_powers_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)
# Out:
#                  name  Gender Eye color   Race        Hair color  Height  \
# 169         Chameleon    Male         -      -                 -   -99.0
# 188  Crimson Crusader    Male      blue      -  Strawberry Blond   -99.0
# 419              Luna  Female         -  Human                 -   -99.0
# 364         JJ Powell    Male         -      -                 -   -99.0
# 712         Weapon XI    Male         -      -                 -   -99.0
#
#          Publisher Skin color Alignment  Weight  ...  Reality Warping  \
# 169      DC Comics          -       bad   -99.0  ...            False
# 188  Marvel Comics          -      good   -99.0  ...            False
# 419  Marvel Comics          -      good   -99.0  ...            False
# 364    ABC Studios          -      good   -99.0  ...            False
# 712  Marvel Comics          -       bad   -99.0  ...            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 169       False             False        False          False
# 188       False             False        False          False
# 419       False             False        False          False
# 364       False             False        False          False
# 712       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  \
# 169                  False          False        False       False
# 188                  False          False        False       False
# 419                  False          False        False       False
# 364                  False          False        False       False
# 712                  False          False        False       False
#
#      Power Count
# 169            1
# 188            4
# 419            1
# 364            1
# 712            7
#
# [5 rows x 178 columns]

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 5      Absorbing Man    Male      blue              Human           No Hair
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 5     193.0      Marvel Comics          -       bad   122.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 729   165.0      Marvel Comics          -      good    52.0  ...
# 730   304.8      Marvel Comics      white      good   -99.0  ...
# 731    66.0       George Lucas      green      good    17.0  ...
# 732   170.0          DC Comics          -      good    57.0  ...
# 733   185.0          DC Comics          -       bad    81.0  ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 5              False       False             False        False
# ..               ...         ...               ...          ...
# 729            False       False             False        False
# 730            False       False             False        False
# 731            False       False             False        False
# 732            False       False             False        False
# 733            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 5            False                  False          False        False
# ..             ...                    ...            ...          ...
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 5         False           11
# ..          ...          ...
# 729       False            3
# 730       False            6
# 731       False           19
# 732       False            8
# 733       False            4
#
# [484 rows x 178 columns]

# %%
question_2_df.Race.value_counts()
# Out:
# Human                 162
# -                     150
# Mutant                 51
# Human / Radiation      11
# Android                 8
# Symbiote                8
# Alien                   6
# Cyborg                  6
# Demon                   6
# Asgardian               5
# Kryptonian              5
# Atlantean               5
# Inhuman                 4
# Human / Altered         3
# New God                 3
# God / Eternal           3
# Saiyan                  2
# Human-Kree              2
# Frost Giant             2
# Eternal                 2
# Demi-God                2
# Metahuman               2
# Amazon                  2
# Strontian               1
# Bizarro                 1
# Korugaran               1
# Bolovaxian              1
# Czarnian                1
# Kakarantharaian         1
# Cosmic Entity           1
# Human / Cosmic          1
# Yautja                  1
# Maiar                   1
# Talokite                1
# Gorilla                 1
# Human-Vuldarian         1
# Xenomorph XX121         1
# Flora Colossus          1
# Rodian                  1
# Yoda's species          1
# Zombie                  1
# Icthyo Sapien           1
# Dathomirian Zabrak      1
# Neyaphem                1
# Zen-Whoberian           1
# Human-Spartoi           1
# Clone                   1
# Tamaranean              1
# Animal                  1
# Luphomoid               1
# Human-Vulcan            1
# Gungan                  1
# Vampire                 1
# Ungaran                 1
# Mutant / Clone          1
# Martian                 1
# Human / Clone           1
# Name: Race, dtype: int64

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=question_2_df["Height"],
    y=question_2_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[(question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male"
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female"
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other"
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
heroes_and_powers_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight  ...  Reality Warping  \
# 0      Marvel Comics          -      good   441.0  ...            False
# 1  Dark Horse Comics       blue      good    65.0  ...            False
# 2          DC Comics        red      good    90.0  ...            False
# 3      Marvel Comics          -       bad   441.0  ...            False
# 4      Marvel Comics          -       bad   -99.0  ...            False
#
#    Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 0       False             False        False          False
# 1       False             False        False          False
# 2       False             False        False          False
# 3       False             False        False          False
# 4       False             False        False          False
#
#    Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  Power Count
# 0                  False          False        False       False            7
# 1                  False          False        False       False           16
# 2                  False          False        False       False            1
# 3                  False          False        False       False            8
# 4                  False          False        False       False           14
#
# [5 rows x 178 columns]

# %%
# Your code here 
# dropping columns now easier than always selecting columns using the powers index
question_3_df = heroes_and_powers_df.copy()

power_pub_cols = list(powers_df.index)
power_pub_cols.append("Publisher")
question_3_df = question_3_df[power_pub_cols]

#get rid of rows where publisher is not DC or Marvel
question_3_df = question_3_df[(question_3_df['Publisher'] == 'Marvel Comics') |\
                              (question_3_df['Publisher'] == 'DC Comics')]
question_3_df.head()
# Out:
#    Agility  Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0    False                 True               False                  False
# 2    False                False                True                  False
# 3    False                 True               False                  False
# 4    False                False               False                   True
# 5    False                False               False                  False
#
#    Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0            False        True    False              False   False
# 2            False       False    False              False   False
# 3            False       False    False              False   False
# 4            False       False    False              False    True
# 5             True        True    False               True   False
#
#    Danger Sense  ...  Reality Warping  Odin Force  Symbiote Costume  \
# 0         False  ...            False       False             False
# 2         False  ...            False       False             False
# 3         False  ...            False       False             False
# 4         False  ...            False       False             False
# 5         False  ...            False       False             False
#
#    Speed Force  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 0        False          False                  False          False
# 2        False          False                  False          False
# 3        False          False                  False          False
# 4        False          False                  False          False
# 5        False          False                  False          False
#
#    Omnipresent  Omniscient      Publisher
# 0        False       False  Marvel Comics
# 2        False       False      DC Comics
# 3        False       False  Marvel Comics
# 4        False       False  Marvel Comics
# 5        False       False  Marvel Comics
#
# [5 rows x 168 columns]

# %%
question_3_df = question_3_df.groupby('Publisher').sum().T

# %%
question_3_df
# Out:
# Publisher              DC Comics  Marvel Comics
# Agility                       71            126
# Accelerated Healing           51            100
# Lantern Power Ring            11              0
# Dimensional Awareness          7             16
# Cold Resistance               15             25
# ...                          ...            ...
# Phoenix Force                  0              1
# Molecular Dissipation          1              0
# Vision - Cryo                  1              0
# Omnipresent                    0              1
# Omniscient                     0              1
#
# [167 rows x 2 columns]

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == ['DC Comics', 'Marvel Comics', 'Superpower Name']

# %%
#need to tidy it up
question_3_df.index.name = "Superpower Name"
question_3_df.reset_index(inplace=True)

question_3_df
# Out:
# Publisher        Superpower Name  DC Comics  Marvel Comics
# 0                        Agility         71            126
# 1            Accelerated Healing         51            100
# 2             Lantern Power Ring         11              0
# 3          Dimensional Awareness          7             16
# 4                Cold Resistance         15             25
# ..                           ...        ...            ...
# 162                Phoenix Force          0              1
# 163        Molecular Dissipation          1              0
# 164                Vision - Cryo          1              0
# 165                  Omnipresent          0              1
# 166                   Omniscient          0              1
#
# [167 rows x 3 columns]

# %%
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == ['DC Comics', 'Marvel Comics', 'Superpower Name']

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(by="Marvel Comics", ascending=False)[:5]
marvel_most_common
# Out:
# Publisher Superpower Name  Marvel Comics
# 17         Super Strength            204
# 5              Durability            154
# 25                Stamina            150
# 30            Super Speed            137
# 0                 Agility            126

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common
# Out:
# Publisher Superpower Name  DC Comics
# 17         Super Strength        109
# 25                Stamina         90
# 8                  Flight         86
# 30            Super Speed         79
# 5              Durability         71

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"],
    height=marvel_most_common["Marvel Comics"]
)
ax2.bar(
    x=dc_most_common["Superpower Name"],
    height=dc_most_common["DC Comics"]
)

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
Which powers co-occurr most frequently in each race of heroes?

Interested in seeing the distribution of powers by race, to see if specific
powers are more common with humans, others with mutants etc. 
However, it would be a bit similar to the example just worked through, 
and the co-currence idea would be a little more interesting, and would require 
solving a problem that I've not yet come across
"""

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %%
# create dictionary of all power pairs and value, set to 0
# make simplified table with just powers and race
# iterate through each row and make list of all True power
# iterate through list update the power pair value in the dictionary if 
# both are present
#

# %%
powers_df.index
# Out:
# Index(['Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight', 'Danger Sense',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=167)

# %%
#tidy up table

powers_race_df = heroes_and_powers_df.copy()

power_pub_cols = list(powers_df.index)
power_pub_cols.append("Race")
powers_race_df = powers_race_df[power_pub_cols]


powers_race_df.head()
# Out:
#    Agility  Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0    False                 True               False                  False
# 1     True                 True               False                  False
# 2    False                False                True                  False
# 3    False                 True               False                  False
# 4    False                False               False                   True
#
#    Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0            False        True    False              False   False
# 1             True        True    False              False   False
# 2            False       False    False              False   False
# 3            False       False    False              False   False
# 4            False       False    False              False    True
#
#    Danger Sense  ...  Reality Warping  Odin Force  Symbiote Costume  \
# 0         False  ...            False       False             False
# 1         False  ...            False       False             False
# 2         False  ...            False       False             False
# 3         False  ...            False       False             False
# 4         False  ...            False       False             False
#
#    Speed Force  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 0        False          False                  False          False
# 1        False          False                  False          False
# 2        False          False                  False          False
# 3        False          False                  False          False
# 4        False          False                  False          False
#
#    Omnipresent  Omniscient               Race
# 0        False       False              Human
# 1        False       False      Icthyo Sapien
# 2        False       False            Ungaran
# 3        False       False  Human / Radiation
# 4        False       False      Cosmic Entity
#
# [5 rows x 168 columns]

# %%
#Replace '-' with 'Unspecified'
powers_race_df['Race'].replace({'-':'Unspecified'}, inplace=True)
print(powers_race_df['Race'].value_counts().head())

heroes_and_powers_df['Race'].replace({'-':'Unspecified'}, inplace=True)
print(heroes_and_powers_df['Race'].value_counts().head())
# Out:
# Unspecified          242
# Human                191
# Mutant                61
# God / Eternal         14
# Human / Radiation     11
# Name: Race, dtype: int64
# Unspecified          242
# Human                191
# Mutant                61
# God / Eternal         14
# Human / Radiation     11
# Name: Race, dtype: int64

# %%
#create dictionary with races as keys, using list of races taken from
#merged dataframe

power_pair_dict ={}

for race in heroes_and_powers_df['Race'].unique():
    power_pair_dict[race]=[]  

race_i=0
list_of_races = powers_race_df['Race'].to_list()
list_of_races = ['Unspecified' if lr =='-' else lr for lr in list_of_races]

power_pair_dict
# Out:
# {'Human': [],
#  'Icthyo Sapien': [],
#  'Ungaran': [],
#  'Human / Radiation': [],
#  'Cosmic Entity': [],
#  'Unspecified': [],
#  'Cyborg': [],
#  'Xenomorph XX121': [],
#  'Android': [],
#  'Vampire': [],
#  'Mutant': [],
#  'God / Eternal': [],
#  'Symbiote': [],
#  'Atlantean': [],
#  'Alien': [],
#  'Neyaphem': [],
#  'New God': [],
#  'Alpha': [],
#  'Bizarro': [],
#  'Inhuman': [],
#  'Metahuman': [],
#  'Demon': [],
#  'Human / Clone': [],
#  'Human-Kree': [],
#  'Dathomirian Zabrak': [],
#  'Amazon': [],
#  'Human / Cosmic': [],
#  'Human / Altered': [],
#  'Kryptonian': [],
#  'Kakarantharaian': [],
#  'Zen-Whoberian': [],
#  'Strontian': [],
#  'Saiyan': [],
#  'Gorilla': [],
#  'Rodian': [],
#  'Flora Colossus': [],
#  'Human-Vuldarian': [],
#  'Asgardian': [],
#  'Demi-God': [],
#  'Eternal': [],
#  'Gungan': [],
#  'Bolovaxian': [],
#  'Animal': [],
#  'Czarnian': [],
#  'Martian': [],
#  'Spartoi': [],
#  'Luphomoid': [],
#  'Parademon': [],
#  'Yautja': [],
#  'Maiar': [],
#  'Clone': [],
#  'Talokite': [],
#  'Korugaran': [],
#  'Zombie': [],
#  'Human-Vulcan': [],
#  'Human-Spartoi': [],
#  'Tamaranean': [],
#  'Frost Giant': [],
#  'Mutant / Clone': [],
#  "Yoda's species": []}

# %%
# iterate through each row
# for each hero make a list of powers
# isolate each power in that list in turn and pair it up, one by one, 
# with every other power to the right of it in the list
# for each pair, add pair:1 as a dictionary to the list of dicts in dict['race']
# if it doens't already exist. If it does exist, add 1 to the pair:value

rows_powers = powers_race_df.apply(lambda row: row[row == True].index, axis=1)
for row_powers in rows_powers:
    left_i=1
    race=list_of_races[race_i]
    for power in row_powers:        
        for r in range(len(row_powers)-left_i):  
            search_key = power + " ~ " + row_powers[left_i+r]
            if not power_pair_dict[race]:
                first_one = {search_key:1}
                power_pair_dict[race].append(first_one)
            else:
                no_record=False
                for inner_dict in power_pair_dict[race]:
                    if search_key in inner_dict.keys():
                        inner_dict[search_key] +=1
                        break
                    else:
                        no_record=True
                if no_record:
                    new_one={search_key:1}
                    power_pair_dict[race].append(new_one)
                        
        left_i+=1
    race_i+=1               

power_pair_dict
# Out:
# {'Human': [{'Accelerated Healing ~ Durability': 26},
#   {'Accelerated Healing ~ Longevity': 13},
#   {'Accelerated Healing ~ Super Strength': 37},
#   {'Accelerated Healing ~ Stamina': 34},
#   {'Accelerated Healing ~ Camouflage': 2},
#   {'Accelerated Healing ~ Self-Sustenance': 6},
#   {'Durability ~ Longevity': 10},
#   {'Durability ~ Super Strength': 52},
#   {'Durability ~ Stamina': 40},
#   {'Durability ~ Camouflage': 2},
#   {'Durability ~ Self-Sustenance': 5},
#   {'Longevity ~ Super Strength': 15},
#   {'Longevity ~ Stamina': 14},
#   {'Longevity ~ Camouflage': 2},
#   {'Longevity ~ Self-Sustenance': 5},
#   {'Super Strength ~ Stamina': 54},
#   {'Super Strength ~ Camouflage': 3},
#   {'Super Strength ~ Self-Sustenance': 6},
#   {'Stamina ~ Camouflage': 3},
#   {'Stamina ~ Self-Sustenance': 6},
#   {'Camouflage ~ Self-Sustenance': 1},
#   {'Cold Resistance ~ Durability': 8},
#   {'Cold Resistance ~ Energy Absorption': 4},
#   {'Cold Resistance ~ Super Strength': 8},
#   {'Cold Resistance ~ Invulnerability': 2},
#   {'Cold Resistance ~ Elemental Transmogrification': 1},
#   {'Cold Resistance ~ Fire Resistance': 1},
#   {'Cold Resistance ~ Natural Armor': 2},
#   {'Cold Resistance ~ Molecular Manipulation': 1},
#   {'Cold Resistance ~ Heat Resistance': 5},
#   {'Cold Resistance ~ Matter Absorption': 1},
#   {'Durability ~ Energy Absorption': 10},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Invulnerability': 15},
#   {'Durability ~ Elemental Transmogrification': 2},
#   {'Durability ~ Fire Resistance': 3},
#   {'Durability ~ Natural Armor': 6},
#   {'Durability ~ Molecular Manipulation': 2},
#   {'Durability ~ Heat Resistance': 6},
#   {'Durability ~ Matter Absorption': 1},
#   {'Energy Absorption ~ Super Strength': 10},
#   {'Energy Absorption ~ Invulnerability': 6},
#   {'Energy Absorption ~ Elemental Transmogrification': 2},
#   {'Energy Absorption ~ Fire Resistance': 2},
#   {'Energy Absorption ~ Natural Armor': 2},
#   {'Energy Absorption ~ Molecular Manipulation': 3},
#   {'Energy Absorption ~ Heat Resistance': 5},
#   {'Energy Absorption ~ Matter Absorption': 3},
#   {'Super Strength ~ Invulnerability': 20},
#   {'Super Strength ~ Elemental Transmogrification': 1},
#   {'Super Strength ~ Fire Resistance': 2},
#   {'Super Strength ~ Natural Armor': 8},
#   {'Super Strength ~ Molecular Manipulation': 5},
#   {'Super Strength ~ Heat Resistance': 8},
#   {'Super Strength ~ Matter Absorption': 3},
#   {'Invulnerability ~ Elemental Transmogrification': 2},
#   {'Invulnerability ~ Fire Resistance': 2},
#   {'Invulnerability ~ Natural Armor': 3},
#   {'Invulnerability ~ Molecular Manipulation': 2},
#   {'Invulnerability ~ Heat Resistance': 4},
#   {'Invulnerability ~ Matter Absorption': 2},
#   {'Elemental Transmogrification ~ Fire Resistance': 1},
#   {'Elemental Transmogrification ~ Natural Armor': 1},
#   {'Elemental Transmogrification ~ Molecular Manipulation': 1},
#   {'Elemental Transmogrification ~ Heat Resistance': 1},
#   {'Elemental Transmogrification ~ Matter Absorption': 1},
#   {'Fire Resistance ~ Natural Armor': 1},
#   {'Fire Resistance ~ Molecular Manipulation': 1},
#   {'Fire Resistance ~ Heat Resistance': 2},
#   {'Fire Resistance ~ Matter Absorption': 1},
#   {'Natural Armor ~ Molecular Manipulation': 1},
#   {'Natural Armor ~ Heat Resistance': 2},
#   {'Natural Armor ~ Matter Absorption': 2},
#   {'Molecular Manipulation ~ Heat Resistance': 2},
#   {'Molecular Manipulation ~ Matter Absorption': 2},
#   {'Heat Resistance ~ Matter Absorption': 1},
#   {'Durability ~ Stealth': 21},
#   {'Durability ~ Flight': 20},
#   {'Durability ~ Marksmanship': 20},
#   {'Durability ~ Weapons Master': 16},
#   {'Durability ~ Intelligence': 16},
#   {'Durability ~ Super Speed': 40},
#   {'Durability ~ Fire Resistance': 1},
#   {'Durability ~ Enhanced Sight': 3},
#   {'Durability ~ Power Suit': 11},
#   {'Stealth ~ Flight': 8},
#   {'Stealth ~ Marksmanship': 42},
#   {'Stealth ~ Weapons Master': 41},
#   {'Stealth ~ Intelligence': 32},
#   {'Stealth ~ Super Speed': 21},
#   {'Stealth ~ Fire Resistance': 1},
#   {'Stealth ~ Enhanced Sight': 4},
#   {'Stealth ~ Power Suit': 7},
#   {'Flight ~ Marksmanship': 11},
#   {'Flight ~ Weapons Master': 7},
#   {'Flight ~ Intelligence': 11},
#   {'Flight ~ Super Speed': 31},
#   {'Flight ~ Fire Resistance': 2},
#   {'Flight ~ Enhanced Sight': 3},
#   {'Flight ~ Power Suit': 9},
#   {'Marksmanship ~ Weapons Master': 42},
#   {'Marksmanship ~ Intelligence': 26},
#   {'Marksmanship ~ Super Speed': 25},
#   {'Marksmanship ~ Fire Resistance': 1},
#   {'Marksmanship ~ Enhanced Sight': 2},
#   {'Marksmanship ~ Power Suit': 9},
#   {'Weapons Master ~ Intelligence': 28},
#   {'Weapons Master ~ Super Speed': 15},
#   {'Weapons Master ~ Fire Resistance': 1},
#   {'Weapons Master ~ Enhanced Sight': 2},
#   {'Weapons Master ~ Power Suit': 10},
#   {'Intelligence ~ Super Speed': 14},
#   {'Intelligence ~ Fire Resistance': 1},
#   {'Intelligence ~ Enhanced Sight': 3},
#   {'Intelligence ~ Power Suit': 10},
#   {'Super Speed ~ Fire Resistance': 2},
#   {'Super Speed ~ Enhanced Sight': 4},
#   {'Super Speed ~ Power Suit': 9},
#   {'Fire Resistance ~ Enhanced Sight': 1},
#   {'Fire Resistance ~ Power Suit': 1},
#   {'Enhanced Sight ~ Power Suit': 2},
#   {'Agility ~ Accelerated Healing': 31},
#   {'Agility ~ Stealth': 52},
#   {'Agility ~ Energy Absorption': 7},
#   {'Agility ~ Danger Sense': 18},
#   {'Agility ~ Marksmanship': 42},
#   {'Agility ~ Weapons Master': 38},
#   {'Agility ~ Longevity': 13},
#   {'Agility ~ Super Strength': 58},
#   {'Agility ~ Energy Blasts': 19},
#   {'Agility ~ Stamina': 73},
#   {'Agility ~ Super Speed': 51},
#   {'Agility ~ Enhanced Senses': 18},
#   {'Agility ~ Jump': 13},
#   {'Agility ~ Shapeshifting': 12},
#   {'Agility ~ Immortality': 5},
#   {'Agility ~ Invulnerability': 13},
#   {'Agility ~ Elasticity': 3},
#   {'Agility ~ Substance Secretion': 8},
#   {'Agility ~ Enhanced Hearing': 11},
#   {'Agility ~ Natural Armor': 5},
#   {'Agility ~ Adaptation': 1},
#   {'Agility ~ Gliding': 3},
#   {'Agility ~ Natural Weapons': 13},
#   {'Agility ~ Wallcrawling': 15},
#   {'Agility ~ Matter Absorption': 2},
#   {'Agility ~ Vision - Thermal': 2},
#   {'Accelerated Healing ~ Stealth': 17},
#   {'Accelerated Healing ~ Energy Absorption': 9},
#   {'Accelerated Healing ~ Danger Sense': 14},
#   {'Accelerated Healing ~ Marksmanship': 15},
#   {'Accelerated Healing ~ Weapons Master': 7},
#   {'Accelerated Healing ~ Longevity': 1},
#   {'Accelerated Healing ~ Super Strength': 1},
#   {'Accelerated Healing ~ Energy Blasts': 13},
#   {'Accelerated Healing ~ Stamina': 1},
#   {'Accelerated Healing ~ Super Speed': 35},
#   {'Accelerated Healing ~ Enhanced Senses': 15},
#   {'Accelerated Healing ~ Jump': 12},
#   {'Accelerated Healing ~ Shapeshifting': 6},
#   {'Accelerated Healing ~ Immortality': 4},
#   {'Accelerated Healing ~ Invulnerability': 9},
#   {'Accelerated Healing ~ Elasticity': 2},
#   {'Accelerated Healing ~ Substance Secretion': 8},
#   {'Accelerated Healing ~ Enhanced Hearing': 6},
#   {'Accelerated Healing ~ Natural Armor': 2},
#   {'Accelerated Healing ~ Adaptation': 1},
#   {'Accelerated Healing ~ Gliding': 1},
#   {'Accelerated Healing ~ Natural Weapons': 9},
#   {'Accelerated Healing ~ Wallcrawling': 11},
#   {'Accelerated Healing ~ Matter Absorption': 2},
#   {'Accelerated Healing ~ Vision - Thermal': 3},
#   {'Stealth ~ Energy Absorption': 2},
#   {'Stealth ~ Danger Sense': 12},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Longevity': 6},
#   {'Stealth ~ Super Strength': 23},
#   {'Stealth ~ Energy Blasts': 7},
#   {'Stealth ~ Stamina': 53},
#   {'Stealth ~ Super Speed': 1},
#   {'Stealth ~ Enhanced Senses': 10},
#   {'Stealth ~ Jump': 11},
#   {'Stealth ~ Shapeshifting': 6},
#   {'Stealth ~ Immortality': 2},
#   {'Stealth ~ Invulnerability': 3},
#   {'Stealth ~ Elasticity': 2},
#   {'Stealth ~ Substance Secretion': 6},
#   {'Stealth ~ Enhanced Hearing': 7},
#   {'Stealth ~ Natural Armor': 1},
#   {'Stealth ~ Adaptation': 1},
#   {'Stealth ~ Gliding': 3},
#   {'Stealth ~ Natural Weapons': 7},
#   {'Stealth ~ Wallcrawling': 9},
#   {'Stealth ~ Matter Absorption': 1},
#   {'Stealth ~ Vision - Thermal': 1},
#   {'Energy Absorption ~ Danger Sense': 3},
#   {'Energy Absorption ~ Marksmanship': 4},
#   {'Energy Absorption ~ Weapons Master': 2},
#   {'Energy Absorption ~ Longevity': 5},
#   {'Energy Absorption ~ Super Strength': 1},
#   {'Energy Absorption ~ Energy Blasts': 9},
#   {'Energy Absorption ~ Stamina': 10},
#   {'Energy Absorption ~ Super Speed': 11},
#   {'Energy Absorption ~ Enhanced Senses': 4},
#   {'Energy Absorption ~ Jump': 1},
#   {'Energy Absorption ~ Shapeshifting': 3},
#   {'Energy Absorption ~ Immortality': 2},
#   {'Energy Absorption ~ Invulnerability': 1},
#   {'Energy Absorption ~ Elasticity': 1},
#   {'Energy Absorption ~ Substance Secretion': 1},
#   {'Energy Absorption ~ Enhanced Hearing': 2},
#   {'Energy Absorption ~ Natural Armor': 1},
#   {'Energy Absorption ~ Adaptation': 1},
#   {'Energy Absorption ~ Gliding': 1},
#   {'Energy Absorption ~ Natural Weapons': 2},
#   {'Energy Absorption ~ Wallcrawling': 1},
#   {'Energy Absorption ~ Matter Absorption': 1},
#   {'Energy Absorption ~ Vision - Thermal': 5},
#   {'Danger Sense ~ Marksmanship': 10},
#   {'Danger Sense ~ Weapons Master': 5},
#   {'Danger Sense ~ Longevity': 3},
#   {'Danger Sense ~ Super Strength': 16},
#   {'Danger Sense ~ Energy Blasts': 5},
#   {'Danger Sense ~ Stamina': 13},
#   {'Danger Sense ~ Super Speed': 16},
#   {'Danger Sense ~ Enhanced Senses': 9},
#   {'Danger Sense ~ Jump': 10},
#   {'Danger Sense ~ Shapeshifting': 2},
#   {'Danger Sense ~ Immortality': 2},
#   {'Danger Sense ~ Invulnerability': 3},
#   {'Danger Sense ~ Elasticity': 1},
#   {'Danger Sense ~ Substance Secretion': 6},
#   {'Danger Sense ~ Enhanced Hearing': 5},
#   {'Danger Sense ~ Natural Armor': 1},
#   {'Danger Sense ~ Adaptation': 1},
#   {'Danger Sense ~ Gliding': 1},
#   {'Danger Sense ~ Natural Weapons': 9},
#   {'Danger Sense ~ Wallcrawling': 10},
#   {'Danger Sense ~ Matter Absorption': 1},
#   {'Danger Sense ~ Vision - Thermal': 1},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Longevity': 6},
#   {'Marksmanship ~ Super Strength': 26},
#   {'Marksmanship ~ Energy Blasts': 14},
#   {'Marksmanship ~ Stamina': 46},
#   {'Marksmanship ~ Super Speed': 1},
#   {'Marksmanship ~ Enhanced Senses': 8},
#   {'Marksmanship ~ Jump': 9},
#   {'Marksmanship ~ Shapeshifting': 2},
#   {'Marksmanship ~ Immortality': 2},
#   {'Marksmanship ~ Invulnerability': 2},
#   {'Marksmanship ~ Elasticity': 1},
#   {'Marksmanship ~ Substance Secretion': 7},
#   {'Marksmanship ~ Enhanced Hearing': 5},
#   {'Marksmanship ~ Natural Armor': 1},
#   {'Marksmanship ~ Adaptation': 1},
#   {'Marksmanship ~ Gliding': 3},
#   {'Marksmanship ~ Natural Weapons': 5},
#   {'Marksmanship ~ Wallcrawling': 8},
#   {'Marksmanship ~ Matter Absorption': 1},
#   {'Marksmanship ~ Vision - Thermal': 3},
#   {'Weapons Master ~ Longevity': 10},
#   {'Weapons Master ~ Super Strength': 17},
#   {'Weapons Master ~ Energy Blasts': 12},
#   {'Weapons Master ~ Stamina': 40},
#   {'Weapons Master ~ Super Speed': 1},
#   {'Weapons Master ~ Enhanced Senses': 8},
#   {'Weapons Master ~ Jump': 5},
#   {'Weapons Master ~ Shapeshifting': 2},
#   {'Weapons Master ~ Immortality': 1},
#   {'Weapons Master ~ Invulnerability': 3},
#   {'Weapons Master ~ Elasticity': 1},
#   {'Weapons Master ~ Substance Secretion': 1},
#   {'Weapons Master ~ Enhanced Hearing': 5},
#   {'Weapons Master ~ Natural Armor': 1},
#   {'Weapons Master ~ Adaptation': 1},
#   {'Weapons Master ~ Gliding': 3},
#   {'Weapons Master ~ Natural Weapons': 1},
#   {'Weapons Master ~ Wallcrawling': 2},
#   {'Weapons Master ~ Matter Absorption': 1},
#   {'Weapons Master ~ Vision - Thermal': 1},
#   {'Longevity ~ Super Strength': 1},
#   {'Longevity ~ Energy Blasts': 8},
#   {'Longevity ~ Stamina': 1},
#   {'Longevity ~ Super Speed': 12},
#   {'Longevity ~ Enhanced Senses': 8},
#   {'Longevity ~ Jump': 2},
#   {'Longevity ~ Shapeshifting': 2},
#   {'Longevity ~ Immortality': 2},
#   {'Longevity ~ Invulnerability': 4},
#   {'Longevity ~ Elasticity': 1},
#   {'Longevity ~ Substance Secretion': 1},
#   {'Longevity ~ Enhanced Hearing': 4},
#   {'Longevity ~ Natural Armor': 1},
#   {'Longevity ~ Adaptation': 1},
#   {'Longevity ~ Gliding': 1},
#   {'Longevity ~ Natural Weapons': 1},
#   {'Longevity ~ Wallcrawling': 2},
#   {'Longevity ~ Matter Absorption': 1},
#   {'Longevity ~ Vision - Thermal': 1},
#   {'Super Strength ~ Energy Blasts': 28},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Super Speed': 60},
#   {'Super Strength ~ Enhanced Senses': 18},
#   {'Super Strength ~ Jump': 16},
#   {'Super Strength ~ Shapeshifting': 12},
#   {'Super Strength ~ Immortality': 4},
#   {'Super Strength ~ Invulnerability': 1},
#   {'Super Strength ~ Elasticity': 3},
#   {'Super Strength ~ Substance Secretion': 8},
#   {'Super Strength ~ Enhanced Hearing': 8},
#   {'Super Strength ~ Natural Armor': 1},
#   {'Super Strength ~ Adaptation': 1},
#   {'Super Strength ~ Gliding': 4},
#   {'Super Strength ~ Natural Weapons': 16},
#   {'Super Strength ~ Wallcrawling': 16},
#   {'Super Strength ~ Matter Absorption': 1},
#   {'Super Strength ~ Vision - Thermal': 5},
#   {'Energy Blasts ~ Stamina': 18},
#   {'Energy Blasts ~ Super Speed': 22},
#   {'Energy Blasts ~ Enhanced Senses': 6},
#   {'Energy Blasts ~ Jump': 4},
#   {'Energy Blasts ~ Shapeshifting': 3},
#   {'Energy Blasts ~ Immortality': 2},
#   {'Energy Blasts ~ Invulnerability': 8},
#   {'Energy Blasts ~ Elasticity': 1},
#   {'Energy Blasts ~ Substance Secretion': 1},
#   {'Energy Blasts ~ Enhanced Hearing': 5},
#   {'Energy Blasts ~ Natural Armor': 1},
#   {'Energy Blasts ~ Adaptation': 1},
#   {'Energy Blasts ~ Gliding': 1},
#   {'Energy Blasts ~ Natural Weapons': 1},
#   {'Energy Blasts ~ Wallcrawling': 2},
#   {'Energy Blasts ~ Matter Absorption': 1},
#   {'Energy Blasts ~ Vision - Thermal': 5},
#   {'Stamina ~ Super Speed': 54},
#   {'Stamina ~ Enhanced Senses': 18},
#   {'Stamina ~ Jump': 15},
#   {'Stamina ~ Shapeshifting': 6},
#   {'Stamina ~ Immortality': 4},
#   {'Stamina ~ Invulnerability': 13},
#   {'Stamina ~ Elasticity': 1},
#   {'Stamina ~ Substance Secretion': 6},
#   {'Stamina ~ Enhanced Hearing': 9},
#   {'Stamina ~ Natural Armor': 3},
#   {'Stamina ~ Adaptation': 1},
#   {'Stamina ~ Gliding': 3},
#   {'Stamina ~ Natural Weapons': 10},
#   {'Stamina ~ Wallcrawling': 14},
#   {'Stamina ~ Matter Absorption': 2},
#   {'Stamina ~ Vision - Thermal': 3},
#   {'Super Speed ~ Enhanced Senses': 21},
#   {'Super Speed ~ Jump': 15},
#   {'Super Speed ~ Shapeshifting': 8},
#   {'Super Speed ~ Immortality': 3},
#   {'Super Speed ~ Invulnerability': 11},
#   {'Super Speed ~ Elasticity': 1},
#   {'Super Speed ~ Substance Secretion': 7},
#   {'Super Speed ~ Enhanced Hearing': 9},
#   {'Super Speed ~ Natural Armor': 5},
#   {'Super Speed ~ Adaptation': 1},
#   {'Super Speed ~ Gliding': 3},
#   {'Super Speed ~ Natural Weapons': 12},
#   {'Super Speed ~ Wallcrawling': 16},
#   {'Super Speed ~ Matter Absorption': 2},
#   {'Super Speed ~ Vision - Thermal': 4},
#   {'Enhanced Senses ~ Jump': 10},
#   {'Enhanced Senses ~ Shapeshifting': 3},
#   {'Enhanced Senses ~ Immortality': 1},
#   {'Enhanced Senses ~ Invulnerability': 5},
#   {'Enhanced Senses ~ Elasticity': 1},
#   {'Enhanced Senses ~ Substance Secretion': 5},
#   {'Enhanced Senses ~ Enhanced Hearing': 7},
#   {'Enhanced Senses ~ Natural Armor': 2},
#   {'Enhanced Senses ~ Adaptation': 1},
#   {'Enhanced Senses ~ Gliding': 1},
#   {'Enhanced Senses ~ Natural Weapons': 6},
#   {'Enhanced Senses ~ Wallcrawling': 6},
#   {'Enhanced Senses ~ Matter Absorption': 1},
#   {'Enhanced Senses ~ Vision - Thermal': 1},
#   {'Jump ~ Shapeshifting': 2},
#   {'Jump ~ Immortality': 1},
#   {'Jump ~ Invulnerability': 4},
#   {'Jump ~ Elasticity': 1},
#   {'Jump ~ Substance Secretion': 6},
#   {'Jump ~ Enhanced Hearing': 4},
#   {'Jump ~ Natural Armor': 3},
#   {'Jump ~ Adaptation': 1},
#   {'Jump ~ Gliding': 1},
#   {'Jump ~ Natural Weapons': 8},
#   {'Jump ~ Wallcrawling': 9},
#   {'Jump ~ Matter Absorption': 1},
#   {'Jump ~ Vision - Thermal': 1},
#   {'Shapeshifting ~ Immortality': 2},
#   {'Shapeshifting ~ Invulnerability': 5},
#   {'Shapeshifting ~ Elasticity': 3},
#   {'Shapeshifting ~ Substance Secretion': 2},
#   {'Shapeshifting ~ Enhanced Hearing': 4},
#   {'Shapeshifting ~ Natural Armor': 3},
#   {'Shapeshifting ~ Adaptation': 1},
#   {'Shapeshifting ~ Gliding': 1},
#   {'Shapeshifting ~ Natural Weapons': 5},
#   {'Shapeshifting ~ Wallcrawling': 4},
#   {'Shapeshifting ~ Matter Absorption': 2},
#   {'Shapeshifting ~ Vision - Thermal': 2},
#   {'Immortality ~ Invulnerability': 4},
#   {'Immortality ~ Elasticity': 2},
#   {'Immortality ~ Substance Secretion': 1},
#   {'Immortality ~ Enhanced Hearing': 2},
#   {'Immortality ~ Natural Armor': 1},
#   {'Immortality ~ Adaptation': 1},
#   {'Immortality ~ Gliding': 1},
#   {'Immortality ~ Natural Weapons': 1},
#   {'Immortality ~ Wallcrawling': 1},
#   {'Immortality ~ Matter Absorption': 1},
#   {'Immortality ~ Vision - Thermal': 1},
#   {'Invulnerability ~ Elasticity': 3},
#   {'Invulnerability ~ Substance Secretion': 2},
#   {'Invulnerability ~ Enhanced Hearing': 3},
#   {'Invulnerability ~ Natural Armor': 1},
#   {'Invulnerability ~ Adaptation': 1},
#   {'Invulnerability ~ Gliding': 1},
#   {'Invulnerability ~ Natural Weapons': 2},
#   {'Invulnerability ~ Wallcrawling': 1},
#   {'Invulnerability ~ Matter Absorption': 1},
#   {'Invulnerability ~ Vision - Thermal': 2},
#   {'Elasticity ~ Substance Secretion': 1},
#   {'Elasticity ~ Enhanced Hearing': 1},
#   {'Elasticity ~ Natural Armor': 1},
#   {'Elasticity ~ Adaptation': 1},
#   {'Elasticity ~ Gliding': 1},
#   {'Elasticity ~ Natural Weapons': 1},
#   {'Elasticity ~ Wallcrawling': 1},
#   {'Elasticity ~ Matter Absorption': 1},
#   {'Elasticity ~ Vision - Thermal': 1},
#   {'Substance Secretion ~ Enhanced Hearing': 1},
#   {'Substance Secretion ~ Natural Armor': 1},
#   {'Substance Secretion ~ Adaptation': 1},
#   {'Substance Secretion ~ Gliding': 1},
#   {'Substance Secretion ~ Natural Weapons': 5},
#   {'Substance Secretion ~ Wallcrawling': 6},
#   {'Substance Secretion ~ Matter Absorption': 1},
#   {'Substance Secretion ~ Vision - Thermal': 1},
#   {'Enhanced Hearing ~ Natural Armor': 1},
#   {'Enhanced Hearing ~ Adaptation': 1},
#   {'Enhanced Hearing ~ Gliding': 1},
#   {'Enhanced Hearing ~ Natural Weapons': 4},
#   {'Enhanced Hearing ~ Wallcrawling': 4},
#   {'Enhanced Hearing ~ Matter Absorption': 1},
#   {'Enhanced Hearing ~ Vision - Thermal': 1},
#   {'Natural Armor ~ Adaptation': 1},
#   {'Natural Armor ~ Gliding': 1},
#   {'Natural Armor ~ Natural Weapons': 6},
#   {'Natural Armor ~ Wallcrawling': 3},
#   {'Natural Armor ~ Matter Absorption': 1},
#   {'Natural Armor ~ Vision - Thermal': 1},
#   {'Adaptation ~ Gliding': 1},
#   {'Adaptation ~ Natural Weapons': 1},
#   {'Adaptation ~ Wallcrawling': 1},
#   {'Adaptation ~ Matter Absorption': 1},
#   {'Adaptation ~ Vision - Thermal': 1},
#   {'Gliding ~ Natural Weapons': 1},
#   {'Gliding ~ Wallcrawling': 1},
#   {'Gliding ~ Matter Absorption': 1},
#   {'Gliding ~ Vision - Thermal': 1},
#   {'Natural Weapons ~ Wallcrawling': 10},
#   {'Natural Weapons ~ Matter Absorption': 1},
#   {'Natural Weapons ~ Vision - Thermal': 1},
#   {'Wallcrawling ~ Matter Absorption': 1},
#   {'Wallcrawling ~ Vision - Thermal': 1},
#   {'Matter Absorption ~ Vision - Thermal': 1},
#   {'Animal Attributes ~ Telepathy': 2},
#   {'Animal Attributes ~ Energy Blasts': 1},
#   {'Animal Attributes ~ Animal Oriented Powers': 13},
#   {'Animal Attributes ~ Empathy': 3},
#   {'Telepathy ~ Energy Blasts': 6},
#   {'Telepathy ~ Animal Oriented Powers': 4},
#   {'Telepathy ~ Empathy': 2},
#   {'Energy Blasts ~ Animal Oriented Powers': 2},
#   {'Energy Blasts ~ Empathy': 4},
#   {'Animal Oriented Powers ~ Empathy': 2},
#   {'Intelligence ~ Size Changing': 4},
#   {'Agility ~ Stealth': 1},
#   {'Agility ~ Intelligence': 30},
#   {'Agility ~ Super Strength': 1},
#   {'Agility ~ Telepathy': 7},
#   {'Agility ~ Size Changing': 6},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Animal Oriented Powers': 17},
#   {'Agility ~ Animal Control': 3},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Super Strength': 1},
#   {'Stealth ~ Telepathy': 6},
#   {'Stealth ~ Size Changing': 4},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Animal Oriented Powers': 10},
#   {'Stealth ~ Animal Control': 3},
#   {'Intelligence ~ Super Strength': 23},
#   {'Intelligence ~ Telepathy': 6},
#   {'Intelligence ~ Size Changing': 1},
#   {'Intelligence ~ Stamina': 32},
#   {'Intelligence ~ Animal Oriented Powers': 3},
#   {'Intelligence ~ Animal Control': 3},
#   {'Super Strength ~ Telepathy': 4},
#   {'Super Strength ~ Size Changing': 8},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Animal Oriented Powers': 18},
#   {'Super Strength ~ Animal Control': 2},
#   {'Telepathy ~ Size Changing': 1},
#   {'Telepathy ~ Stamina': 5},
#   {'Telepathy ~ Animal Oriented Powers': 1},
#   {'Telepathy ~ Animal Control': 2},
#   {'Size Changing ~ Stamina': 2},
#   {'Size Changing ~ Animal Oriented Powers': 4},
#   {'Size Changing ~ Animal Control': 1},
#   {'Stamina ~ Animal Oriented Powers': 14},
#   {'Stamina ~ Animal Control': 3},
#   {'Animal Oriented Powers ~ Animal Control': 2},
#   {'Agility ~ Accelerated Healing': 1},
#   {'Agility ~ Durability': 36},
#   {'Agility ~ Super Strength': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Super Speed': 1},
#   {'Agility ~ Reflexes': 54},
#   {'Agility ~ Psionic Powers': 6},
#   {'Agility ~ Toxin and Disease Resistance': 13},
#   {'Agility ~ Enhanced Touch': 2},
#   {'Agility ~ Wallcrawling': 1},
#   {'Agility ~ Web Creation': 7},
#   {'Accelerated Healing ~ Super Strength': 1},
#   {'Accelerated Healing ~ Stamina': 1},
#   {'Accelerated Healing ~ Super Speed': 1},
#   {'Accelerated Healing ~ Reflexes': 26},
#   {'Accelerated Healing ~ Psionic Powers': 5},
#   {'Accelerated Healing ~ Toxin and Disease Resistance': 11},
#   {'Accelerated Healing ~ Enhanced Touch': 2},
#   {'Accelerated Healing ~ Wallcrawling': 1},
#   {'Accelerated Healing ~ Web Creation': 7},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Super Speed': 1},
#   {'Durability ~ Reflexes': 32},
#   {'Durability ~ Psionic Powers': 5},
#   {'Durability ~ Toxin and Disease Resistance': 12},
#   {'Durability ~ Enhanced Touch': 1},
#   {'Durability ~ Wallcrawling': 11},
#   {'Durability ~ Web Creation': 6},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Super Speed': 1},
#   {'Super Strength ~ Reflexes': 41},
#   {'Super Strength ~ Psionic Powers': 5},
#   {'Super Strength ~ Toxin and Disease Resistance': 12},
#   {'Super Strength ~ Enhanced Touch': 1},
#   {'Super Strength ~ Wallcrawling': 1},
#   {'Super Strength ~ Web Creation': 7},
#   {'Stamina ~ Super Speed': 1},
#   {'Stamina ~ Reflexes': 57},
#   {'Stamina ~ Psionic Powers': 4},
#   {'Stamina ~ Toxin and Disease Resistance': 12},
#   {'Stamina ~ Enhanced Touch': 3},
#   {'Stamina ~ Wallcrawling': 1},
#   {'Stamina ~ Web Creation': 8},
#   {'Super Speed ~ Reflexes': 46},
#   {'Super Speed ~ Psionic Powers': 7},
#   {'Super Speed ~ Toxin and Disease Resistance': 10},
#   {'Super Speed ~ Enhanced Touch': 2},
#   {'Super Speed ~ Wallcrawling': 1},
#   {'Super Speed ~ Web Creation': 7},
#   {'Reflexes ~ Psionic Powers': 6},
#   {'Reflexes ~ Toxin and Disease Resistance': 11},
#   {'Reflexes ~ Enhanced Touch': 2},
#   {'Reflexes ~ Wallcrawling': 11},
#   {'Reflexes ~ Web Creation': 7},
#   {'Psionic Powers ~ Toxin and Disease Resistance': 2},
#   {'Psionic Powers ~ Enhanced Touch': 1},
#   {'Psionic Powers ~ Wallcrawling': 1},
#   {'Psionic Powers ~ Web Creation': 1},
#   {'Toxin and Disease Resistance ~ Enhanced Touch': 1},
#   {'Toxin and Disease Resistance ~ Wallcrawling': 5},
#   {'Toxin and Disease Resistance ~ Web Creation': 4},
#   {'Enhanced Touch ~ Wallcrawling': 1},
#   {'Enhanced Touch ~ Web Creation': 1},
#   {'Wallcrawling ~ Web Creation': 7},
#   {'Flight ~ Super Strength': 34},
#   {'Flight ~ Size Changing': 5},
#   {'Flight ~ Density Control': 4},
#   {'Flight ~ Gliding': 2},
#   {'Super Strength ~ Size Changing': 1},
#   {'Super Strength ~ Density Control': 6},
#   {'Super Strength ~ Gliding': 1},
#   {'Size Changing ~ Density Control': 3},
#   {'Size Changing ~ Gliding': 1},
#   {'Density Control ~ Gliding': 1},
#   {'Weapons Master ~ Super Strength': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Super Speed': 1},
#   {'Weapons Master ~ Weapon-based Powers': 16},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Super Speed': 1},
#   {'Super Strength ~ Weapon-based Powers': 13},
#   {'Stamina ~ Super Speed': 1},
#   {'Stamina ~ Weapon-based Powers': 20},
#   {'Super Speed ~ Weapon-based Powers': 13},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Super Speed': 1},
#   {'Durability ~ Enhanced Memory': 4},
#   {'Durability ~ Reflexes': 1},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Super Speed': 1},
#   {'Super Strength ~ Enhanced Memory': 4},
#   {'Super Strength ~ Reflexes': 1},
#   {'Stamina ~ Super Speed': 1},
#   {'Stamina ~ Enhanced Memory': 7},
#   {'Stamina ~ Reflexes': 1},
#   {'Super Speed ~ Enhanced Memory': 5},
#   {'Super Speed ~ Reflexes': 1},
#   {'Enhanced Memory ~ Reflexes': 6},
#   {'Flight ~ Audio Control': 1},
#   {'Flight ~ Force Fields': 20},
#   {'Flight ~ Enhanced Hearing': 7},
#   {'Flight ~ Sonar': 1},
#   {'Flight ~ Sonic Scream': 1},
#   {'Audio Control ~ Force Fields': 1},
#   {'Audio Control ~ Enhanced Hearing': 1},
#   {'Audio Control ~ Sonar': 1},
#   {'Audio Control ~ Sonic Scream': 2},
#   {'Force Fields ~ Enhanced Hearing': 4},
#   {'Force Fields ~ Sonar': 1},
#   {'Force Fields ~ Sonic Scream': 1},
#   {'Enhanced Hearing ~ Sonar': 1},
#   {'Enhanced Hearing ~ Sonic Scream': 1},
#   {'Sonar ~ Sonic Scream': 1},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Weapon-based Powers': 11},
#   {'Stealth ~ Reflexes': 32},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Weapon-based Powers': 15},
#   {'Marksmanship ~ Reflexes': 30},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Weapon-based Powers': 1},
#   {'Weapons Master ~ Reflexes': 23},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Weapon-based Powers': 12},
#   {'Intelligence ~ Reflexes': 18},
#   {'Stamina ~ Weapon-based Powers': 1},
#   {'Stamina ~ Reflexes': 1},
#   {'Weapon-based Powers ~ Reflexes': 13},
#   {'Agility ~ Stealth': 1},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Peak Human Condition': 20},
#   {'Agility ~ Toxin and Disease Resistance': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Peak Human Condition': 17},
#   {'Stealth ~ Toxin and Disease Resistance': 7},
#   {'Weapons Master ~ Peak Human Condition': 18},
#   {'Weapons Master ~ Toxin and Disease Resistance': 4},
#   {'Peak Human Condition ~ Toxin and Disease Resistance': 3},
#   {'Agility ~ Durability': 1},
#   {'Agility ~ Stealth': 1},
#   {'Agility ~ Underwater breathing': 4},
#   {'Agility ~ Marksmanship': 1},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Intelligence': 1},
#   {'Agility ~ Super Strength': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Super Speed': 1},
#   {'Agility ~ Weapon-based Powers': 18},
#   {'Agility ~ Peak Human Condition': 1},
#   {'Agility ~ Reflexes': 1},
#   {'Agility ~ Gliding': 1},
#   {'Agility ~ Power Suit': 8},
#   {'Agility ~ Vision - Night': 10},
#   {'Agility ~ Vision - Infrared': 6},
#   {'Durability ~ Stealth': 1},
#   {'Durability ~ Underwater breathing': 6},
#   {'Durability ~ Marksmanship': 1},
#   {'Durability ~ Weapons Master': 1},
#   {'Durability ~ Intelligence': 1},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Super Speed': 1},
#   {'Durability ~ Weapon-based Powers': 14},
#   {'Durability ~ Peak Human Condition': 6},
#   {'Durability ~ Reflexes': 1},
#   {'Durability ~ Gliding': 2},
#   {'Durability ~ Power Suit': 1},
#   {'Durability ~ Vision - Night': 10},
#   {'Durability ~ Vision - Infrared': 6},
#   {'Stealth ~ Underwater breathing': 3},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Super Strength': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Super Speed': 1},
#   {'Stealth ~ Weapon-based Powers': 1},
#   {'Stealth ~ Peak Human Condition': 1},
#   {'Stealth ~ Reflexes': 1},
#   {'Stealth ~ Gliding': 1},
#   {'Stealth ~ Power Suit': 1},
#   {'Stealth ~ Vision - Night': 7},
#   {'Stealth ~ Vision - Infrared': 3},
#   {'Underwater breathing ~ Marksmanship': 5},
#   {'Underwater breathing ~ Weapons Master': 3},
#   {'Underwater breathing ~ Intelligence': 2},
#   {'Underwater breathing ~ Super Strength': 6},
#   {'Underwater breathing ~ Stamina': 5},
#   {'Underwater breathing ~ Super Speed': 6},
#   {'Underwater breathing ~ Weapon-based Powers': 4},
#   {'Underwater breathing ~ Peak Human Condition': 3},
#   {'Underwater breathing ~ Reflexes': 4},
#   {'Underwater breathing ~ Gliding': 2},
#   {'Underwater breathing ~ Power Suit': 5},
#   {'Underwater breathing ~ Vision - Night': 4},
#   {'Underwater breathing ~ Vision - Infrared': 3},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Super Strength': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Super Speed': 1},
#   {'Marksmanship ~ Weapon-based Powers': 1},
#   {'Marksmanship ~ Peak Human Condition': 18},
#   {'Marksmanship ~ Reflexes': 1},
#   {'Marksmanship ~ Gliding': 1},
#   {'Marksmanship ~ Power Suit': 1},
#   {'Marksmanship ~ Vision - Night': 9},
#   {'Marksmanship ~ Vision - Infrared': 3},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Super Strength': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Super Speed': 1},
#   {'Weapons Master ~ Weapon-based Powers': 1},
#   {'Weapons Master ~ Peak Human Condition': 1},
#   {'Weapons Master ~ Reflexes': 1},
#   {'Weapons Master ~ Gliding': 1},
#   {'Weapons Master ~ Power Suit': 1},
#   {'Weapons Master ~ Vision - Night': 4},
#   {'Weapons Master ~ Vision - Infrared': 4},
#   {'Intelligence ~ Super Strength': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Super Speed': 1},
#   {'Intelligence ~ Weapon-based Powers': 1},
#   {'Intelligence ~ Peak Human Condition': 12},
#   {'Intelligence ~ Reflexes': 1},
#   {'Intelligence ~ Gliding': 2},
#   {'Intelligence ~ Power Suit': 1},
#   {'Intelligence ~ Vision - Night': 3},
#   {'Intelligence ~ Vision - Infrared': 3},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Super Speed': 1},
#   {'Super Strength ~ Weapon-based Powers': 1},
#   {'Super Strength ~ Peak Human Condition': 7},
#   {'Super Strength ~ Reflexes': 1},
#   {'Super Strength ~ Gliding': 1},
#   {'Super Strength ~ Power Suit': 12},
#   {'Super Strength ~ Vision - Night': 10},
#   {'Super Strength ~ Vision - Infrared': 6},
#   {'Stamina ~ Super Speed': 1},
#   {'Stamina ~ Weapon-based Powers': 1},
#   {'Stamina ~ Peak Human Condition': 18},
#   {'Stamina ~ Reflexes': 1},
#   {'Stamina ~ Gliding': 1},
#   {'Stamina ~ Power Suit': 8},
#   {'Stamina ~ Vision - Night': 11},
#   {'Stamina ~ Vision - Infrared': 5},
#   {'Super Speed ~ Weapon-based Powers': 1},
#   {'Super Speed ~ Peak Human Condition': 4},
#   {'Super Speed ~ Reflexes': 1},
#   {'Super Speed ~ Gliding': 1},
#   {'Super Speed ~ Power Suit': 1},
#   {'Super Speed ~ Vision - Night': 10},
#   {'Super Speed ~ Vision - Infrared': 5},
#   {'Weapon-based Powers ~ Peak Human Condition': 9},
#   {'Weapon-based Powers ~ Reflexes': 1},
#   {'Weapon-based Powers ~ Gliding': 2},
#   {'Weapon-based Powers ~ Power Suit': 9},
#   {'Weapon-based Powers ~ Vision - Night': 5},
#   {'Weapon-based Powers ~ Vision - Infrared': 3},
#   {'Peak Human Condition ~ Reflexes': 10},
#   {'Peak Human Condition ~ Gliding': 2},
#   {'Peak Human Condition ~ Power Suit': 4},
#   {'Peak Human Condition ~ Vision - Night': 4},
#   {'Peak Human Condition ~ Vision - Infrared': 3},
#   {'Reflexes ~ Gliding': 2},
#   {'Reflexes ~ Power Suit': 5},
#   {'Reflexes ~ Vision - Night': 11},
#   {'Reflexes ~ Vision - Infrared': 4},
#   {'Gliding ~ Power Suit': 2},
#   {'Gliding ~ Vision - Night': 2},
#   {'Gliding ~ Vision - Infrared': 2},
#   {'Power Suit ~ Vision - Night': 4},
#   {'Power Suit ~ Vision - Infrared': 5},
#   {'Vision - Night ~ Vision - Infrared': 3},
#   {'Agility ~ Durability': 1},
#   {'Agility ~ Stealth': 1},
#   {'Agility ~ Underwater breathing': 1},
#   {'Agility ~ Marksmanship': 1},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Intelligence': 1},
#   {'Agility ~ Super Strength': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Super Speed': 1},
#   {'Agility ~ Weapon-based Powers': 1},
#   {'Agility ~ Peak Human Condition': 1},
#   {'Agility ~ Reflexes': 1},
#   {'Agility ~ Gliding': 1},
#   {'Agility ~ Power Suit': 1},
#   {'Agility ~ Vision - Night': 1},
#   {'Agility ~ Vision - Infrared': 1},
#   {'Durability ~ Stealth': 1},
#   {'Durability ~ Underwater breathing': 1},
#   {'Durability ~ Marksmanship': 1},
#   {'Durability ~ Weapons Master': 1},
#   {'Durability ~ Intelligence': 1},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Super Speed': 1},
#   {'Durability ~ Weapon-based Powers': 1},
#   {'Durability ~ Peak Human Condition': 1},
#   {'Durability ~ Reflexes': 1},
#   {'Durability ~ Gliding': 1},
#   {'Durability ~ Power Suit': 1},
#   {'Durability ~ Vision - Night': 1},
#   {'Durability ~ Vision - Infrared': 1},
#   {'Stealth ~ Underwater breathing': 1},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Super Strength': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Super Speed': 1},
#   {'Stealth ~ Weapon-based Powers': 1},
#   {'Stealth ~ Peak Human Condition': 1},
#   {'Stealth ~ Reflexes': 1},
#   {'Stealth ~ Gliding': 1},
#   {'Stealth ~ Power Suit': 1},
#   {'Stealth ~ Vision - Night': 1},
#   {'Stealth ~ Vision - Infrared': 1},
#   {'Underwater breathing ~ Marksmanship': 1},
#   {'Underwater breathing ~ Weapons Master': 1},
#   {'Underwater breathing ~ Intelligence': 1},
#   {'Underwater breathing ~ Super Strength': 1},
#   {'Underwater breathing ~ Stamina': 1},
#   {'Underwater breathing ~ Super Speed': 1},
#   {'Underwater breathing ~ Weapon-based Powers': 1},
#   {'Underwater breathing ~ Peak Human Condition': 1},
#   {'Underwater breathing ~ Reflexes': 1},
#   {'Underwater breathing ~ Gliding': 1},
#   {'Underwater breathing ~ Power Suit': 1},
#   {'Underwater breathing ~ Vision - Night': 1},
#   {'Underwater breathing ~ Vision - Infrared': 1},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Super Strength': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Super Speed': 1},
#   {'Marksmanship ~ Weapon-based Powers': 1},
#   {'Marksmanship ~ Peak Human Condition': 1},
#   {'Marksmanship ~ Reflexes': 1},
#   {'Marksmanship ~ Gliding': 1},
#   {'Marksmanship ~ Power Suit': 1},
#   {'Marksmanship ~ Vision - Night': 1},
#   {'Marksmanship ~ Vision - Infrared': 1},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Super Strength': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Super Speed': 1},
#   {'Weapons Master ~ Weapon-based Powers': 1},
#   {'Weapons Master ~ Peak Human Condition': 1},
#   {'Weapons Master ~ Reflexes': 1},
#   {'Weapons Master ~ Gliding': 1},
#   {'Weapons Master ~ Power Suit': 1},
#   {'Weapons Master ~ Vision - Night': 1},
#   {'Weapons Master ~ Vision - Infrared': 1},
#   {'Intelligence ~ Super Strength': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Super Speed': 1},
#   {'Intelligence ~ Weapon-based Powers': 1},
#   {'Intelligence ~ Peak Human Condition': 1},
#   {'Intelligence ~ Reflexes': 1},
#   {'Intelligence ~ Gliding': 1},
#   {'Intelligence ~ Power Suit': 1},
#   {'Intelligence ~ Vision - Night': 1},
#   {'Intelligence ~ Vision - Infrared': 1},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Super Speed': 1},
#   {'Super Strength ~ Weapon-based Powers': 1},
#   {'Super Strength ~ Peak Human Condition': 1},
#   {'Super Strength ~ Reflexes': 1},
#   {'Super Strength ~ Gliding': 1},
#   {'Super Strength ~ Power Suit': 1},
#   {'Super Strength ~ Vision - Night': 1},
#   {'Super Strength ~ Vision - Infrared': 1},
#   {'Stamina ~ Super Speed': 1},
#   {'Stamina ~ Weapon-based Powers': 1},
#   {'Stamina ~ Peak Human Condition': 1},
#   {'Stamina ~ Reflexes': 1},
#   {'Stamina ~ Gliding': 1},
#   {'Stamina ~ Power Suit': 1},
#   {'Stamina ~ Vision - Night': 1},
#   {'Stamina ~ Vision - Infrared': 1},
#   {'Super Speed ~ Weapon-based Powers': 1},
#   {'Super Speed ~ Peak Human Condition': 1},
#   {'Super Speed ~ Reflexes': 1},
#   {'Super Speed ~ Gliding': 1},
#   {'Super Speed ~ Power Suit': 1},
#   {'Super Speed ~ Vision - Night': 1},
#   {'Super Speed ~ Vision - Infrared': 1},
#   {'Weapon-based Powers ~ Peak Human Condition': 1},
#   {'Weapon-based Powers ~ Reflexes': 1},
#   {'Weapon-based Powers ~ Gliding': 1},
#   {'Weapon-based Powers ~ Power Suit': 1},
#   {'Weapon-based Powers ~ Vision - Night': 1},
#   {'Weapon-based Powers ~ Vision - Infrared': 1},
#   {'Peak Human Condition ~ Reflexes': 1},
#   {'Peak Human Condition ~ Gliding': 1},
#   {'Peak Human Condition ~ Power Suit': 1},
#   {'Peak Human Condition ~ Vision - Night': 1},
#   {'Peak Human Condition ~ Vision - Infrared': 1},
#   {'Reflexes ~ Gliding': 1},
#   {'Reflexes ~ Power Suit': 1},
#   {'Reflexes ~ Vision - Night': 1},
#   {'Reflexes ~ Vision - Infrared': 1},
#   {'Gliding ~ Power Suit': 1},
#   {'Gliding ~ Vision - Night': 1},
#   {'Gliding ~ Vision - Infrared': 1},
#   {'Power Suit ~ Vision - Night': 1},
#   {'Power Suit ~ Vision - Infrared': 1},
#   {'Vision - Night ~ Vision - Infrared': 1},
#   {'Agility ~ Stealth': 1},
#   {'Agility ~ Marksmanship': 1},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Intelligence': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Weapon-based Powers': 1},
#   {'Agility ~ Peak Human Condition': 1},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Weapon-based Powers': 1},
#   {'Stealth ~ Peak Human Condition': 1},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Weapon-based Powers': 1},
#   {'Marksmanship ~ Peak Human Condition': 1},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Weapon-based Powers': 1},
#   {'Weapons Master ~ Peak Human Condition': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Weapon-based Powers': 1},
#   {'Intelligence ~ Peak Human Condition': 1},
#   {'Stamina ~ Weapon-based Powers': 1},
#   {'Stamina ~ Peak Human Condition': 1},
#   {'Weapon-based Powers ~ Peak Human Condition': 1},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Dexterity': 3},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Dexterity': 2},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Dexterity': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Dexterity': 2},
#   {'Stamina ~ Dexterity': 3},
#   {'Agility ~ Durability': 1},
#   {'Agility ~ Flight': 21},
#   {'Agility ~ Animal Attributes': 12},
#   {'Agility ~ Super Strength': 1},
#   {'Agility ~ Size Changing': 1},
#   {'Agility ~ Super Speed': 1},
#   {'Agility ~ Animal Oriented Powers': 1},
#   {'Agility ~ Shapeshifting': 1},
#   {'Agility ~ Empathy': 5},
#   {'Agility ~ Natural Armor': 1},
#   {'Agility ~ Natural Weapons': 1},
#   {'Agility ~ Sub-Mariner': 3},
#   {'Agility ~ Wallcrawling': 1},
#   {'Durability ~ Flight': 1},
#   {'Durability ~ Animal Attributes': 10},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Size Changing': 3},
#   {'Durability ~ Super Speed': 1},
#   {'Durability ~ Animal Oriented Powers': 10},
#   {'Durability ~ Shapeshifting': 5},
#   ...],
#  'Icthyo Sapien': [{'Agility ~ Accelerated Healing': 1},
#   {'Agility ~ Cold Resistance': 1},
#   {'Agility ~ Durability': 1},
#   {'Agility ~ Underwater breathing': 1},
#   {'Agility ~ Marksmanship': 1},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Longevity': 1},
#   {'Agility ~ Intelligence': 1},
#   {'Agility ~ Super Strength': 1},
#   {'Agility ~ Telepathy': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Immortality': 1},
#   {'Agility ~ Reflexes': 1},
#   {'Agility ~ Enhanced Sight': 1},
#   {'Agility ~ Sub-Mariner': 1},
#   {'Accelerated Healing ~ Cold Resistance': 1},
#   {'Accelerated Healing ~ Durability': 1},
#   {'Accelerated Healing ~ Underwater breathing': 1},
#   {'Accelerated Healing ~ Marksmanship': 1},
#   {'Accelerated Healing ~ Weapons Master': 1},
#   {'Accelerated Healing ~ Longevity': 1},
#   {'Accelerated Healing ~ Intelligence': 1},
#   {'Accelerated Healing ~ Super Strength': 1},
#   {'Accelerated Healing ~ Telepathy': 1},
#   {'Accelerated Healing ~ Stamina': 1},
#   {'Accelerated Healing ~ Immortality': 1},
#   {'Accelerated Healing ~ Reflexes': 1},
#   {'Accelerated Healing ~ Enhanced Sight': 1},
#   {'Accelerated Healing ~ Sub-Mariner': 1},
#   {'Cold Resistance ~ Durability': 1},
#   {'Cold Resistance ~ Underwater breathing': 1},
#   {'Cold Resistance ~ Marksmanship': 1},
#   {'Cold Resistance ~ Weapons Master': 1},
#   {'Cold Resistance ~ Longevity': 1},
#   {'Cold Resistance ~ Intelligence': 1},
#   {'Cold Resistance ~ Super Strength': 1},
#   {'Cold Resistance ~ Telepathy': 1},
#   {'Cold Resistance ~ Stamina': 1},
#   {'Cold Resistance ~ Immortality': 1},
#   {'Cold Resistance ~ Reflexes': 1},
#   {'Cold Resistance ~ Enhanced Sight': 1},
#   {'Cold Resistance ~ Sub-Mariner': 1},
#   {'Durability ~ Underwater breathing': 1},
#   {'Durability ~ Marksmanship': 1},
#   {'Durability ~ Weapons Master': 1},
#   {'Durability ~ Longevity': 1},
#   {'Durability ~ Intelligence': 1},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Telepathy': 1},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Immortality': 1},
#   {'Durability ~ Reflexes': 1},
#   {'Durability ~ Enhanced Sight': 1},
#   {'Durability ~ Sub-Mariner': 1},
#   {'Underwater breathing ~ Marksmanship': 1},
#   {'Underwater breathing ~ Weapons Master': 1},
#   {'Underwater breathing ~ Longevity': 1},
#   {'Underwater breathing ~ Intelligence': 1},
#   {'Underwater breathing ~ Super Strength': 1},
#   {'Underwater breathing ~ Telepathy': 1},
#   {'Underwater breathing ~ Stamina': 1},
#   {'Underwater breathing ~ Immortality': 1},
#   {'Underwater breathing ~ Reflexes': 1},
#   {'Underwater breathing ~ Enhanced Sight': 1},
#   {'Underwater breathing ~ Sub-Mariner': 1},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Longevity': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Super Strength': 1},
#   {'Marksmanship ~ Telepathy': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Immortality': 1},
#   {'Marksmanship ~ Reflexes': 1},
#   {'Marksmanship ~ Enhanced Sight': 1},
#   {'Marksmanship ~ Sub-Mariner': 1},
#   {'Weapons Master ~ Longevity': 1},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Super Strength': 1},
#   {'Weapons Master ~ Telepathy': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Immortality': 1},
#   {'Weapons Master ~ Reflexes': 1},
#   {'Weapons Master ~ Enhanced Sight': 1},
#   {'Weapons Master ~ Sub-Mariner': 1},
#   {'Longevity ~ Intelligence': 1},
#   {'Longevity ~ Super Strength': 1},
#   {'Longevity ~ Telepathy': 1},
#   {'Longevity ~ Stamina': 1},
#   {'Longevity ~ Immortality': 1},
#   {'Longevity ~ Reflexes': 1},
#   {'Longevity ~ Enhanced Sight': 1},
#   {'Longevity ~ Sub-Mariner': 1},
#   {'Intelligence ~ Super Strength': 1},
#   {'Intelligence ~ Telepathy': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Immortality': 1},
#   {'Intelligence ~ Reflexes': 1},
#   {'Intelligence ~ Enhanced Sight': 1},
#   {'Intelligence ~ Sub-Mariner': 1},
#   {'Super Strength ~ Telepathy': 1},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Immortality': 1},
#   {'Super Strength ~ Reflexes': 1},
#   {'Super Strength ~ Enhanced Sight': 1},
#   {'Super Strength ~ Sub-Mariner': 1},
#   {'Telepathy ~ Stamina': 1},
#   {'Telepathy ~ Immortality': 1},
#   {'Telepathy ~ Reflexes': 1},
#   {'Telepathy ~ Enhanced Sight': 1},
#   {'Telepathy ~ Sub-Mariner': 1},
#   {'Stamina ~ Immortality': 1},
#   {'Stamina ~ Reflexes': 1},
#   {'Stamina ~ Enhanced Sight': 1},
#   {'Stamina ~ Sub-Mariner': 1},
#   {'Immortality ~ Reflexes': 1},
#   {'Immortality ~ Enhanced Sight': 1},
#   {'Immortality ~ Sub-Mariner': 1},
#   {'Reflexes ~ Enhanced Sight': 1},
#   {'Reflexes ~ Sub-Mariner': 1},
#   {'Enhanced Sight ~ Sub-Mariner': 1}],
#  'Ungaran': [],
#  'Human / Radiation': [{'Accelerated Healing ~ Intelligence': 1},
#   {'Accelerated Healing ~ Super Strength': 4},
#   {'Accelerated Healing ~ Stamina': 3},
#   {'Accelerated Healing ~ Super Speed': 4},
#   {'Accelerated Healing ~ Invulnerability': 3},
#   {'Accelerated Healing ~ Animation': 1},
#   {'Accelerated Healing ~ Super Breath': 2},
#   {'Intelligence ~ Super Strength': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Super Speed': 1},
#   {'Intelligence ~ Invulnerability': 1},
#   {'Intelligence ~ Animation': 1},
#   {'Intelligence ~ Super Breath': 1},
#   {'Super Strength ~ Stamina': 6},
#   {'Super Strength ~ Super Speed': 5},
#   {'Super Strength ~ Invulnerability': 4},
#   {'Super Strength ~ Animation': 1},
#   {'Super Strength ~ Super Breath': 2},
#   {'Stamina ~ Super Speed': 4},
#   {'Stamina ~ Invulnerability': 3},
#   {'Stamina ~ Animation': 1},
#   {'Stamina ~ Super Breath': 2},
#   {'Super Speed ~ Invulnerability': 3},
#   {'Super Speed ~ Animation': 1},
#   {'Super Speed ~ Super Breath': 3},
#   {'Invulnerability ~ Animation': 1},
#   {'Invulnerability ~ Super Breath': 2},
#   {'Animation ~ Super Breath': 1},
#   {'Agility ~ Accelerated Healing': 2},
#   {'Agility ~ Energy Absorption': 2},
#   {'Agility ~ Flight': 2},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Super Strength': 2},
#   {'Agility ~ Energy Blasts': 2},
#   {'Agility ~ Super Speed': 3},
#   {'Agility ~ Enhanced Senses': 1},
#   {'Agility ~ Immortality': 1},
#   {'Agility ~ Phasing': 1},
#   {'Agility ~ Invulnerability': 2},
#   {'Agility ~ Force Fields': 1},
#   {'Agility ~ Self-Sustenance': 2},
#   {'Agility ~ Radiation Control': 1},
#   {'Agility ~ Technopath/Cyberpath': 1},
#   {'Agility ~ Natural Armor': 1},
#   {'Agility ~ Enhanced Sight': 1},
#   {'Agility ~ Molecular Manipulation': 1},
#   {'Agility ~ Heat Generation': 2},
#   {'Agility ~ Energy Manipulation': 1},
#   {'Agility ~ Time Travel': 1},
#   {'Agility ~ Radiation Immunity': 2},
#   {'Agility ~ Energy Resistance': 1},
#   {'Agility ~ Time Manipulation': 1},
#   {'Agility ~ Invisibility': 1},
#   {'Agility ~ Radiation Absorption': 2},
#   {'Accelerated Healing ~ Energy Absorption': 2},
#   {'Accelerated Healing ~ Flight': 1},
#   {'Accelerated Healing ~ Weapons Master': 1},
#   {'Accelerated Healing ~ Super Strength': 1},
#   {'Accelerated Healing ~ Energy Blasts': 1},
#   {'Accelerated Healing ~ Super Speed': 1},
#   {'Accelerated Healing ~ Enhanced Senses': 1},
#   {'Accelerated Healing ~ Immortality': 1},
#   {'Accelerated Healing ~ Phasing': 1},
#   {'Accelerated Healing ~ Invulnerability': 1},
#   {'Accelerated Healing ~ Force Fields': 1},
#   {'Accelerated Healing ~ Self-Sustenance': 2},
#   {'Accelerated Healing ~ Radiation Control': 2},
#   {'Accelerated Healing ~ Technopath/Cyberpath': 1},
#   {'Accelerated Healing ~ Natural Armor': 1},
#   {'Accelerated Healing ~ Enhanced Sight': 1},
#   {'Accelerated Healing ~ Molecular Manipulation': 1},
#   {'Accelerated Healing ~ Heat Generation': 1},
#   {'Accelerated Healing ~ Energy Manipulation': 1},
#   {'Accelerated Healing ~ Time Travel': 1},
#   {'Accelerated Healing ~ Radiation Immunity': 3},
#   {'Accelerated Healing ~ Energy Resistance': 1},
#   {'Accelerated Healing ~ Time Manipulation': 1},
#   {'Accelerated Healing ~ Invisibility': 1},
#   {'Accelerated Healing ~ Radiation Absorption': 3},
#   {'Energy Absorption ~ Flight': 2},
#   {'Energy Absorption ~ Weapons Master': 1},
#   {'Energy Absorption ~ Super Strength': 2},
#   {'Energy Absorption ~ Energy Blasts': 2},
#   {'Energy Absorption ~ Super Speed': 3},
#   {'Energy Absorption ~ Enhanced Senses': 1},
#   {'Energy Absorption ~ Immortality': 1},
#   {'Energy Absorption ~ Phasing': 1},
#   {'Energy Absorption ~ Invulnerability': 1},
#   {'Energy Absorption ~ Force Fields': 1},
#   {'Energy Absorption ~ Self-Sustenance': 1},
#   {'Energy Absorption ~ Radiation Control': 2},
#   {'Energy Absorption ~ Technopath/Cyberpath': 1},
#   {'Energy Absorption ~ Natural Armor': 1},
#   {'Energy Absorption ~ Enhanced Sight': 1},
#   {'Energy Absorption ~ Molecular Manipulation': 1},
#   {'Energy Absorption ~ Heat Generation': 2},
#   {'Energy Absorption ~ Energy Manipulation': 1},
#   {'Energy Absorption ~ Time Travel': 1},
#   {'Energy Absorption ~ Radiation Immunity': 2},
#   {'Energy Absorption ~ Energy Resistance': 1},
#   {'Energy Absorption ~ Time Manipulation': 1},
#   {'Energy Absorption ~ Invisibility': 1},
#   {'Energy Absorption ~ Radiation Absorption': 2},
#   {'Flight ~ Weapons Master': 1},
# ...
#   {'Stamina ~ Fire Resistance': 1},
#   {'Stamina ~ Toxin and Disease Resistance': 1},
#   {'Stamina ~ Resurrection': 1},
#   {'Invulnerability ~ Self-Sustenance': 1},
#   {'Invulnerability ~ Fire Resistance': 1},
#   {'Invulnerability ~ Toxin and Disease Resistance': 1},
#   {'Invulnerability ~ Resurrection': 1},
#   {'Self-Sustenance ~ Fire Resistance': 1},
#   {'Self-Sustenance ~ Toxin and Disease Resistance': 1},
#   {'Self-Sustenance ~ Resurrection': 1},
#   {'Fire Resistance ~ Toxin and Disease Resistance': 1},
#   {'Fire Resistance ~ Resurrection': 1},
#   {'Toxin and Disease Resistance ~ Resurrection': 1}],
#  'Human-Vulcan': [{'Stealth ~ Longevity': 1},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Super Strength': 1},
#   {'Stealth ~ Telepathy': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Psionic Powers': 1},
#   {'Stealth ~ Enhanced Hearing': 1},
#   {'Stealth ~ Omnilingualism': 1},
#   {'Longevity ~ Intelligence': 1},
#   {'Longevity ~ Super Strength': 1},
#   {'Longevity ~ Telepathy': 1},
#   {'Longevity ~ Stamina': 1},
#   {'Longevity ~ Psionic Powers': 1},
#   {'Longevity ~ Enhanced Hearing': 1},
#   {'Longevity ~ Omnilingualism': 1},
#   {'Intelligence ~ Super Strength': 1},
#   {'Intelligence ~ Telepathy': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Psionic Powers': 1},
#   {'Intelligence ~ Enhanced Hearing': 1},
#   {'Intelligence ~ Omnilingualism': 1},
#   {'Super Strength ~ Telepathy': 1},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Psionic Powers': 1},
#   {'Super Strength ~ Enhanced Hearing': 1},
#   {'Super Strength ~ Omnilingualism': 1},
#   {'Telepathy ~ Stamina': 1},
#   {'Telepathy ~ Psionic Powers': 1},
#   {'Telepathy ~ Enhanced Hearing': 1},
#   {'Telepathy ~ Omnilingualism': 1},
#   {'Stamina ~ Psionic Powers': 1},
#   {'Stamina ~ Enhanced Hearing': 1},
#   {'Stamina ~ Omnilingualism': 1},
#   {'Psionic Powers ~ Enhanced Hearing': 1},
#   {'Psionic Powers ~ Omnilingualism': 1},
#   {'Enhanced Hearing ~ Omnilingualism': 1}],
#  'Human-Spartoi': [{'Agility ~ Durability': 1},
#   {'Agility ~ Marksmanship': 1},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Longevity': 1},
#   {'Agility ~ Intelligence': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Peak Human Condition': 1},
#   {'Durability ~ Marksmanship': 1},
#   {'Durability ~ Weapons Master': 1},
#   {'Durability ~ Longevity': 1},
#   {'Durability ~ Intelligence': 1},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Peak Human Condition': 1},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Longevity': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Peak Human Condition': 1},
#   {'Weapons Master ~ Longevity': 1},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Peak Human Condition': 1},
#   {'Longevity ~ Intelligence': 1},
#   {'Longevity ~ Stamina': 1},
#   {'Longevity ~ Peak Human Condition': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Peak Human Condition': 1},
#   {'Stamina ~ Peak Human Condition': 1}],
#  'Tamaranean': [{'Durability ~ Energy Absorption': 1},
#   {'Durability ~ Flight': 1},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Energy Blasts': 1},
#   {'Durability ~ Invulnerability': 1},
#   {'Durability ~ Omnilingualism': 1},
#   {'Energy Absorption ~ Flight': 1},
#   {'Energy Absorption ~ Super Strength': 1},
#   {'Energy Absorption ~ Energy Blasts': 1},
#   {'Energy Absorption ~ Invulnerability': 1},
#   {'Energy Absorption ~ Omnilingualism': 1},
#   {'Flight ~ Super Strength': 1},
#   {'Flight ~ Energy Blasts': 1},
#   {'Flight ~ Invulnerability': 1},
#   {'Flight ~ Omnilingualism': 1},
#   {'Super Strength ~ Energy Blasts': 1},
#   {'Super Strength ~ Invulnerability': 1},
#   {'Super Strength ~ Omnilingualism': 1},
#   {'Energy Blasts ~ Invulnerability': 1},
#   {'Energy Blasts ~ Omnilingualism': 1},
#   {'Invulnerability ~ Omnilingualism': 1}],
#  'Frost Giant': [{'Durability ~ Longevity': 2},
#   {'Durability ~ Super Strength': 2},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Magic': 1},
#   {'Durability ~ Invulnerability': 1},
#   {'Longevity ~ Super Strength': 2},
#   {'Longevity ~ Stamina': 1},
#   {'Longevity ~ Magic': 1},
#   {'Longevity ~ Invulnerability': 1},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Magic': 1},
#   {'Super Strength ~ Invulnerability': 1},
#   {'Stamina ~ Magic': 1},
#   {'Stamina ~ Invulnerability': 1},
#   {'Magic ~ Invulnerability': 1},
#   {'Cold Resistance ~ Durability': 1},
#   {'Cold Resistance ~ Longevity': 1},
#   {'Cold Resistance ~ Super Strength': 1},
#   {'Cold Resistance ~ Cryokinesis': 1},
#   {'Cold Resistance ~ Immortality': 1},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Cryokinesis': 1},
#   {'Durability ~ Immortality': 1},
#   {'Longevity ~ Super Strength': 1},
#   {'Longevity ~ Cryokinesis': 1},
#   {'Longevity ~ Immortality': 1},
#   {'Super Strength ~ Cryokinesis': 1},
#   {'Super Strength ~ Immortality': 1},
#   {'Cryokinesis ~ Immortality': 1}],
#  'Mutant / Clone': [{'Agility ~ Accelerated Healing': 1},
#   {'Agility ~ Durability': 1},
#   {'Agility ~ Stealth': 1},
#   {'Agility ~ Marksmanship': 1},
#   {'Agility ~ Longevity': 1},
#   {'Agility ~ Super Strength': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Jump': 1},
#   {'Agility ~ Reflexes': 1},
#   {'Agility ~ Enhanced Hearing': 1},
#   {'Agility ~ Enhanced Sight': 1},
#   {'Agility ~ Natural Weapons': 1},
#   {'Agility ~ Enhanced Smell': 1},
#   {'Agility ~ Vision - Telescopic': 1},
#   {'Agility ~ Toxin and Disease Resistance': 1},
#   {'Agility ~ Vision - Night': 1},
#   {'Accelerated Healing ~ Durability': 1},
#   {'Accelerated Healing ~ Stealth': 1},
#   {'Accelerated Healing ~ Marksmanship': 1},
#   {'Accelerated Healing ~ Longevity': 1},
#   {'Accelerated Healing ~ Super Strength': 1},
#   {'Accelerated Healing ~ Stamina': 1},
#   {'Accelerated Healing ~ Jump': 1},
#   {'Accelerated Healing ~ Reflexes': 1},
#   {'Accelerated Healing ~ Enhanced Hearing': 1},
#   {'Accelerated Healing ~ Enhanced Sight': 1},
#   {'Accelerated Healing ~ Natural Weapons': 1},
#   {'Accelerated Healing ~ Enhanced Smell': 1},
#   {'Accelerated Healing ~ Vision - Telescopic': 1},
#   {'Accelerated Healing ~ Toxin and Disease Resistance': 1},
#   {'Accelerated Healing ~ Vision - Night': 1},
#   {'Durability ~ Stealth': 1},
#   {'Durability ~ Marksmanship': 1},
#   {'Durability ~ Longevity': 1},
#   {'Durability ~ Super Strength': 1},
#   {'Durability ~ Stamina': 1},
#   {'Durability ~ Jump': 1},
#   {'Durability ~ Reflexes': 1},
#   {'Durability ~ Enhanced Hearing': 1},
#   {'Durability ~ Enhanced Sight': 1},
#   {'Durability ~ Natural Weapons': 1},
#   {'Durability ~ Enhanced Smell': 1},
#   {'Durability ~ Vision - Telescopic': 1},
#   {'Durability ~ Toxin and Disease Resistance': 1},
#   {'Durability ~ Vision - Night': 1},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Longevity': 1},
#   {'Stealth ~ Super Strength': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Jump': 1},
#   {'Stealth ~ Reflexes': 1},
#   {'Stealth ~ Enhanced Hearing': 1},
#   {'Stealth ~ Enhanced Sight': 1},
#   {'Stealth ~ Natural Weapons': 1},
#   {'Stealth ~ Enhanced Smell': 1},
#   {'Stealth ~ Vision - Telescopic': 1},
#   {'Stealth ~ Toxin and Disease Resistance': 1},
#   {'Stealth ~ Vision - Night': 1},
#   {'Marksmanship ~ Longevity': 1},
#   {'Marksmanship ~ Super Strength': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Jump': 1},
#   {'Marksmanship ~ Reflexes': 1},
#   {'Marksmanship ~ Enhanced Hearing': 1},
#   {'Marksmanship ~ Enhanced Sight': 1},
#   {'Marksmanship ~ Natural Weapons': 1},
#   {'Marksmanship ~ Enhanced Smell': 1},
#   {'Marksmanship ~ Vision - Telescopic': 1},
#   {'Marksmanship ~ Toxin and Disease Resistance': 1},
#   {'Marksmanship ~ Vision - Night': 1},
#   {'Longevity ~ Super Strength': 1},
#   {'Longevity ~ Stamina': 1},
#   {'Longevity ~ Jump': 1},
#   {'Longevity ~ Reflexes': 1},
#   {'Longevity ~ Enhanced Hearing': 1},
#   {'Longevity ~ Enhanced Sight': 1},
#   {'Longevity ~ Natural Weapons': 1},
#   {'Longevity ~ Enhanced Smell': 1},
#   {'Longevity ~ Vision - Telescopic': 1},
#   {'Longevity ~ Toxin and Disease Resistance': 1},
#   {'Longevity ~ Vision - Night': 1},
#   {'Super Strength ~ Stamina': 1},
#   {'Super Strength ~ Jump': 1},
#   {'Super Strength ~ Reflexes': 1},
#   {'Super Strength ~ Enhanced Hearing': 1},
#   {'Super Strength ~ Enhanced Sight': 1},
#   {'Super Strength ~ Natural Weapons': 1},
#   {'Super Strength ~ Enhanced Smell': 1},
#   {'Super Strength ~ Vision - Telescopic': 1},
#   {'Super Strength ~ Toxin and Disease Resistance': 1},
#   {'Super Strength ~ Vision - Night': 1},
#   {'Stamina ~ Jump': 1},
#   {'Stamina ~ Reflexes': 1},
#   {'Stamina ~ Enhanced Hearing': 1},
#   {'Stamina ~ Enhanced Sight': 1},
#   {'Stamina ~ Natural Weapons': 1},
#   {'Stamina ~ Enhanced Smell': 1},
#   {'Stamina ~ Vision - Telescopic': 1},
#   {'Stamina ~ Toxin and Disease Resistance': 1},
#   {'Stamina ~ Vision - Night': 1},
#   {'Jump ~ Reflexes': 1},
#   {'Jump ~ Enhanced Hearing': 1},
#   {'Jump ~ Enhanced Sight': 1},
#   {'Jump ~ Natural Weapons': 1},
#   {'Jump ~ Enhanced Smell': 1},
#   {'Jump ~ Vision - Telescopic': 1},
#   {'Jump ~ Toxin and Disease Resistance': 1},
#   {'Jump ~ Vision - Night': 1},
#   {'Reflexes ~ Enhanced Hearing': 1},
#   {'Reflexes ~ Enhanced Sight': 1},
#   {'Reflexes ~ Natural Weapons': 1},
#   {'Reflexes ~ Enhanced Smell': 1},
#   {'Reflexes ~ Vision - Telescopic': 1},
#   {'Reflexes ~ Toxin and Disease Resistance': 1},
#   {'Reflexes ~ Vision - Night': 1},
#   {'Enhanced Hearing ~ Enhanced Sight': 1},
#   {'Enhanced Hearing ~ Natural Weapons': 1},
#   {'Enhanced Hearing ~ Enhanced Smell': 1},
#   {'Enhanced Hearing ~ Vision - Telescopic': 1},
#   {'Enhanced Hearing ~ Toxin and Disease Resistance': 1},
#   {'Enhanced Hearing ~ Vision - Night': 1},
#   {'Enhanced Sight ~ Natural Weapons': 1},
#   {'Enhanced Sight ~ Enhanced Smell': 1},
#   {'Enhanced Sight ~ Vision - Telescopic': 1},
#   {'Enhanced Sight ~ Toxin and Disease Resistance': 1},
#   {'Enhanced Sight ~ Vision - Night': 1},
#   {'Natural Weapons ~ Enhanced Smell': 1},
#   {'Natural Weapons ~ Vision - Telescopic': 1},
#   {'Natural Weapons ~ Toxin and Disease Resistance': 1},
#   {'Natural Weapons ~ Vision - Night': 1},
#   {'Enhanced Smell ~ Vision - Telescopic': 1},
#   {'Enhanced Smell ~ Toxin and Disease Resistance': 1},
#   {'Enhanced Smell ~ Vision - Night': 1},
#   {'Vision - Telescopic ~ Toxin and Disease Resistance': 1},
#   {'Vision - Telescopic ~ Vision - Night': 1},
#   {'Toxin and Disease Resistance ~ Vision - Night': 1}],
#  "Yoda's species": [{'Agility ~ Stealth': 1},
#   {'Agility ~ Danger Sense': 1},
#   {'Agility ~ Marksmanship': 1},
#   {'Agility ~ Weapons Master': 1},
#   {'Agility ~ Longevity': 1},
#   {'Agility ~ Intelligence': 1},
#   {'Agility ~ Telepathy': 1},
#   {'Agility ~ Energy Blasts': 1},
#   {'Agility ~ Stamina': 1},
#   {'Agility ~ Super Speed': 1},
#   {'Agility ~ Telekinesis': 1},
#   {'Agility ~ Jump': 1},
#   {'Agility ~ Reflexes': 1},
#   {'Agility ~ Force Fields': 1},
#   {'Agility ~ Empathy': 1},
#   {'Agility ~ Precognition': 1},
#   {'Agility ~ Cloaking': 1},
#   {'Agility ~ The Force': 1},
#   {'Stealth ~ Danger Sense': 1},
#   {'Stealth ~ Marksmanship': 1},
#   {'Stealth ~ Weapons Master': 1},
#   {'Stealth ~ Longevity': 1},
#   {'Stealth ~ Intelligence': 1},
#   {'Stealth ~ Telepathy': 1},
#   {'Stealth ~ Energy Blasts': 1},
#   {'Stealth ~ Stamina': 1},
#   {'Stealth ~ Super Speed': 1},
#   {'Stealth ~ Telekinesis': 1},
#   {'Stealth ~ Jump': 1},
#   {'Stealth ~ Reflexes': 1},
#   {'Stealth ~ Force Fields': 1},
#   {'Stealth ~ Empathy': 1},
#   {'Stealth ~ Precognition': 1},
#   {'Stealth ~ Cloaking': 1},
#   {'Stealth ~ The Force': 1},
#   {'Danger Sense ~ Marksmanship': 1},
#   {'Danger Sense ~ Weapons Master': 1},
#   {'Danger Sense ~ Longevity': 1},
#   {'Danger Sense ~ Intelligence': 1},
#   {'Danger Sense ~ Telepathy': 1},
#   {'Danger Sense ~ Energy Blasts': 1},
#   {'Danger Sense ~ Stamina': 1},
#   {'Danger Sense ~ Super Speed': 1},
#   {'Danger Sense ~ Telekinesis': 1},
#   {'Danger Sense ~ Jump': 1},
#   {'Danger Sense ~ Reflexes': 1},
#   {'Danger Sense ~ Force Fields': 1},
#   {'Danger Sense ~ Empathy': 1},
#   {'Danger Sense ~ Precognition': 1},
#   {'Danger Sense ~ Cloaking': 1},
#   {'Danger Sense ~ The Force': 1},
#   {'Marksmanship ~ Weapons Master': 1},
#   {'Marksmanship ~ Longevity': 1},
#   {'Marksmanship ~ Intelligence': 1},
#   {'Marksmanship ~ Telepathy': 1},
#   {'Marksmanship ~ Energy Blasts': 1},
#   {'Marksmanship ~ Stamina': 1},
#   {'Marksmanship ~ Super Speed': 1},
#   {'Marksmanship ~ Telekinesis': 1},
#   {'Marksmanship ~ Jump': 1},
#   {'Marksmanship ~ Reflexes': 1},
#   {'Marksmanship ~ Force Fields': 1},
#   {'Marksmanship ~ Empathy': 1},
#   {'Marksmanship ~ Precognition': 1},
#   {'Marksmanship ~ Cloaking': 1},
#   {'Marksmanship ~ The Force': 1},
#   {'Weapons Master ~ Longevity': 1},
#   {'Weapons Master ~ Intelligence': 1},
#   {'Weapons Master ~ Telepathy': 1},
#   {'Weapons Master ~ Energy Blasts': 1},
#   {'Weapons Master ~ Stamina': 1},
#   {'Weapons Master ~ Super Speed': 1},
#   {'Weapons Master ~ Telekinesis': 1},
#   {'Weapons Master ~ Jump': 1},
#   {'Weapons Master ~ Reflexes': 1},
#   {'Weapons Master ~ Force Fields': 1},
#   {'Weapons Master ~ Empathy': 1},
#   {'Weapons Master ~ Precognition': 1},
#   {'Weapons Master ~ Cloaking': 1},
#   {'Weapons Master ~ The Force': 1},
#   {'Longevity ~ Intelligence': 1},
#   {'Longevity ~ Telepathy': 1},
#   {'Longevity ~ Energy Blasts': 1},
#   {'Longevity ~ Stamina': 1},
#   {'Longevity ~ Super Speed': 1},
#   {'Longevity ~ Telekinesis': 1},
#   {'Longevity ~ Jump': 1},
#   {'Longevity ~ Reflexes': 1},
#   {'Longevity ~ Force Fields': 1},
#   {'Longevity ~ Empathy': 1},
#   {'Longevity ~ Precognition': 1},
#   {'Longevity ~ Cloaking': 1},
#   {'Longevity ~ The Force': 1},
#   {'Intelligence ~ Telepathy': 1},
#   {'Intelligence ~ Energy Blasts': 1},
#   {'Intelligence ~ Stamina': 1},
#   {'Intelligence ~ Super Speed': 1},
#   {'Intelligence ~ Telekinesis': 1},
#   {'Intelligence ~ Jump': 1},
#   {'Intelligence ~ Reflexes': 1},
#   {'Intelligence ~ Force Fields': 1},
#   {'Intelligence ~ Empathy': 1},
#   {'Intelligence ~ Precognition': 1},
#   {'Intelligence ~ Cloaking': 1},
#   {'Intelligence ~ The Force': 1},
#   {'Telepathy ~ Energy Blasts': 1},
#   {'Telepathy ~ Stamina': 1},
#   {'Telepathy ~ Super Speed': 1},
#   {'Telepathy ~ Telekinesis': 1},
#   {'Telepathy ~ Jump': 1},
#   {'Telepathy ~ Reflexes': 1},
#   {'Telepathy ~ Force Fields': 1},
#   {'Telepathy ~ Empathy': 1},
#   {'Telepathy ~ Precognition': 1},
#   {'Telepathy ~ Cloaking': 1},
#   {'Telepathy ~ The Force': 1},
#   {'Energy Blasts ~ Stamina': 1},
#   {'Energy Blasts ~ Super Speed': 1},
#   {'Energy Blasts ~ Telekinesis': 1},
#   {'Energy Blasts ~ Jump': 1},
#   {'Energy Blasts ~ Reflexes': 1},
#   {'Energy Blasts ~ Force Fields': 1},
#   {'Energy Blasts ~ Empathy': 1},
#   {'Energy Blasts ~ Precognition': 1},
#   {'Energy Blasts ~ Cloaking': 1},
#   {'Energy Blasts ~ The Force': 1},
#   {'Stamina ~ Super Speed': 1},
#   {'Stamina ~ Telekinesis': 1},
#   {'Stamina ~ Jump': 1},
#   {'Stamina ~ Reflexes': 1},
#   {'Stamina ~ Force Fields': 1},
#   {'Stamina ~ Empathy': 1},
#   {'Stamina ~ Precognition': 1},
#   {'Stamina ~ Cloaking': 1},
#   {'Stamina ~ The Force': 1},
#   {'Super Speed ~ Telekinesis': 1},
#   {'Super Speed ~ Jump': 1},
#   {'Super Speed ~ Reflexes': 1},
#   {'Super Speed ~ Force Fields': 1},
#   {'Super Speed ~ Empathy': 1},
#   {'Super Speed ~ Precognition': 1},
#   {'Super Speed ~ Cloaking': 1},
#   {'Super Speed ~ The Force': 1},
#   {'Telekinesis ~ Jump': 1},
#   {'Telekinesis ~ Reflexes': 1},
#   {'Telekinesis ~ Force Fields': 1},
#   {'Telekinesis ~ Empathy': 1},
#   {'Telekinesis ~ Precognition': 1},
#   {'Telekinesis ~ Cloaking': 1},
#   {'Telekinesis ~ The Force': 1},
#   {'Jump ~ Reflexes': 1},
#   {'Jump ~ Force Fields': 1},
#   {'Jump ~ Empathy': 1},
#   {'Jump ~ Precognition': 1},
#   {'Jump ~ Cloaking': 1},
#   {'Jump ~ The Force': 1},
#   {'Reflexes ~ Force Fields': 1},
#   {'Reflexes ~ Empathy': 1},
#   {'Reflexes ~ Precognition': 1},
#   {'Reflexes ~ Cloaking': 1},
#   {'Reflexes ~ The Force': 1},
#   {'Force Fields ~ Empathy': 1},
#   {'Force Fields ~ Precognition': 1},
#   {'Force Fields ~ Cloaking': 1},
#   {'Force Fields ~ The Force': 1},
#   {'Empathy ~ Precognition': 1},
#   {'Empathy ~ Cloaking': 1},
#   {'Empathy ~ The Force': 1},
#   {'Precognition ~ Cloaking': 1},
#   {'Precognition ~ The Force': 1},
#   {'Cloaking ~ The Force': 1}]}

# %%
#sort the cocurrences for each race, then create a new dict of five most
# common for each race

top_dict = {}
for r in list_of_races:
    tup_l = [list(d.items()) for d in power_pair_dict[r]]
    flat_list = [item for sublist in tup_l for item in sublist]
    lst_sorted = sorted(flat_list, key=lambda x: x[1], reverse=True)[:5]   
    top_dict[r]=lst_sorted

top_dict
# Out:
# {'Human': [('Agility ~ Stamina', 73),
#   ('Super Strength ~ Super Speed', 60),
#   ('Agility ~ Super Strength', 58),
#   ('Stamina ~ Reflexes', 57),
#   ('Super Strength ~ Stamina', 54)],
#  'Icthyo Sapien': [('Agility ~ Accelerated Healing', 1),
#   ('Agility ~ Cold Resistance', 1),
#   ('Agility ~ Durability', 1),
#   ('Agility ~ Underwater breathing', 1),
#   ('Agility ~ Marksmanship', 1)],
#  'Ungaran': [],
#  'Human / Radiation': [('Super Strength ~ Stamina', 6),
#   ('Durability ~ Super Strength', 6),
#   ('Super Strength ~ Super Speed', 5),
#   ('Durability ~ Stamina', 5),
#   ('Accelerated Healing ~ Super Strength', 4)],
#  'Cosmic Entity': [('Dimensional Awareness ~ Flight', 4),
#   ('Dimensional Awareness ~ Intelligence', 4),
#   ('Dimensional Awareness ~ Super Strength', 4),
#   ('Dimensional Awareness ~ Size Changing', 4),
#   ('Dimensional Awareness ~ Super Speed', 4)],
#  'Unspecified': [('Durability ~ Super Strength', 62),
#   ('Super Strength ~ Super Speed', 56),
#   ('Super Strength ~ Stamina', 50),
#   ('Flight ~ Super Strength', 45),
#   ('Stamina ~ Super Speed', 35)],
#  'Cyborg': [('Durability ~ Super Strength', 7),
#   ('Durability ~ Stamina', 7),
#   ('Super Strength ~ Stamina', 7),
#   ('Super Strength ~ Super Speed', 6),
#   ('Durability ~ Super Speed', 6)],
#  'Xenomorph XX121': [('Agility ~ Cold Resistance', 1),
#   ('Agility ~ Durability', 1),
#   ('Agility ~ Stealth', 1),
#   ('Agility ~ Super Strength', 1),
#   ('Agility ~ Super Speed', 1)],
#  'Android': [('Durability ~ Super Strength', 7),
#   ('Super Strength ~ Super Speed', 7),
#   ('Durability ~ Stamina', 6),
#   ('Durability ~ Super Speed', 6),
#   ('Super Strength ~ Stamina', 6)],
#  'Vampire': [('Agility ~ Accelerated Healing', 2),
#   ('Agility ~ Super Strength', 2),
#   ('Agility ~ Stamina', 2),
#   ('Agility ~ Super Speed', 2),
#   ('Agility ~ Enhanced Senses', 2)],
#  'Mutant': [('Agility ~ Stamina', 21),
#   ('Super Strength ~ Stamina', 20),
#   ('Accelerated Healing ~ Stamina', 20),
#   ('Agility ~ Accelerated Healing', 18),
#   ('Durability ~ Super Strength', 17)],
#  'God / Eternal': [('Super Strength ~ Immortality', 9),
#   ('Flight ~ Super Strength', 8),
#   ('Flight ~ Immortality', 8),
#   ('Intelligence ~ Immortality', 8),
#   ('Accelerated Healing ~ Teleportation', 7)],
#  'Symbiote': [('Accelerated Healing ~ Durability', 8),
#   ('Accelerated Healing ~ Danger Sense', 8),
#   ('Accelerated Healing ~ Super Strength', 8),
#   ('Accelerated Healing ~ Stamina', 8),
#   ('Accelerated Healing ~ Reflexes', 8)],
#  'Atlantean': [('Durability ~ Underwater breathing', 5),
#   ('Durability ~ Super Strength', 5),
#   ('Durability ~ Telepathy', 5),
#   ('Durability ~ Super Speed', 5),
#   ('Underwater breathing ~ Super Strength', 5)],
#  'Alien': [('Durability ~ Super Strength', 5),
#   ('Durability ~ Energy Blasts', 4),
#   ('Super Strength ~ Energy Blasts', 4),
#   ('Agility ~ Durability', 3),
#   ('Agility ~ Super Strength', 3)],
#  'Neyaphem': [('Accelerated Healing ~ Longevity', 1),
#   ('Accelerated Healing ~ Teleportation', 1),
#   ('Accelerated Healing ~ Dimensional Travel', 1),
#   ('Accelerated Healing ~ Shapeshifting', 1),
#   ('Accelerated Healing ~ Regeneration', 1)],
#  'New God': [('Agility ~ Super Strength', 3),
#   ('Agility ~ Stamina', 3),
#   ('Agility ~ Immortality', 3),
#   ('Agility ~ Reflexes', 3),
#   ('Agility ~ Invulnerability', 3)],
#  'Alpha': [('Super Strength ~ Super Speed', 1),
#   ('Super Strength ~ Toxin and Disease Resistance', 1),
#   ('Super Speed ~ Toxin and Disease Resistance', 1),
#   ('Marksmanship ~ Hyperkinesis', 1),
#   ('Marksmanship ~ Spatial Awareness', 1)],
#  'Bizarro': [('Agility ~ Accelerated Healing', 1),
#   ('Agility ~ Durability', 1),
#   ('Agility ~ Energy Absorption', 1),
#   ('Agility ~ Flight', 1),
#   ('Agility ~ Marksmanship', 1)],
#  'Inhuman': [('Super Strength ~ Stamina', 4),
#   ('Super Strength ~ Super Speed', 4),
#   ('Super Strength ~ Reflexes', 4),
#   ('Stamina ~ Super Speed', 4),
#   ('Stamina ~ Reflexes', 4)],
#  'Metahuman': [('Agility ~ Stamina', 2),
#   ('Agility ~ Reflexes', 2),
#   ('Stamina ~ Reflexes', 2),
#   ('Agility ~ Stealth', 1),
#   ('Agility ~ Marksmanship', 1)],
#  'Demon': [('Durability ~ Super Strength', 5),
#   ('Super Strength ~ Stamina', 5),
#   ('Super Strength ~ Magic', 5),
#   ('Agility ~ Super Strength', 4),
#   ('Agility ~ Stamina', 4)],
#  'Human / Clone': [('Agility ~ Stealth', 1),
#   ('Agility ~ Flight', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Weapons Master', 1),
#   ('Agility ~ Intelligence', 1)],
#  'Human-Kree': [('Accelerated Healing ~ Durability', 2),
#   ('Accelerated Healing ~ Flight', 2),
#   ('Accelerated Healing ~ Longevity', 2),
#   ('Accelerated Healing ~ Intelligence', 2),
#   ('Accelerated Healing ~ Precognition', 2)],
#  'Dathomirian Zabrak': [('Agility ~ Durability', 1),
#   ('Agility ~ Stealth', 1),
#   ('Agility ~ Danger Sense', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Weapons Master', 1)],
#  'Amazon': [('Flight ~ Super Strength', 2),
#   ('Flight ~ Super Speed', 2),
#   ('Super Strength ~ Super Speed', 2),
#   ('Accelerated Healing ~ Durability', 1),
#   ('Accelerated Healing ~ Flight', 1)],
#  'Human / Cosmic': [('Accelerated Healing ~ Durability', 2),
#   ('Accelerated Healing ~ Energy Absorption', 2),
#   ('Accelerated Healing ~ Flight', 2),
#   ('Accelerated Healing ~ Super Strength', 2),
#   ('Accelerated Healing ~ Energy Blasts', 2)],
#  'Human / Altered': [('Accelerated Healing ~ Durability', 3),
#   ('Accelerated Healing ~ Stamina', 3),
#   ('Durability ~ Stamina', 3),
#   ('Agility ~ Accelerated Healing', 2),
#   ('Agility ~ Durability', 2)],
#  'Kryptonian': [('Accelerated Healing ~ Flight', 7),
#   ('Accelerated Healing ~ Super Strength', 7),
#   ('Accelerated Healing ~ Stamina', 7),
#   ('Accelerated Healing ~ Super Speed', 7),
#   ('Accelerated Healing ~ Invulnerability', 7)],
#  'Kakarantharaian': [('Accelerated Healing ~ Durability', 1),
#   ('Accelerated Healing ~ Flight', 1),
#   ('Accelerated Healing ~ Longevity', 1),
#   ('Accelerated Healing ~ Super Strength', 1),
#   ('Accelerated Healing ~ Telepathy', 1)],
#  'Zen-Whoberian': [('Agility ~ Accelerated Healing', 1),
#   ('Agility ~ Durability', 1),
#   ('Agility ~ Stealth', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Weapons Master', 1)],
#  'Strontian': [('Agility ~ Accelerated Healing', 1),
#   ('Agility ~ Flight', 1),
#   ('Agility ~ Longevity', 1),
#   ('Agility ~ Super Strength', 1),
#   ('Agility ~ Stamina', 1)],
#  'Saiyan': [('Agility ~ Accelerated Healing', 2),
#   ('Agility ~ Flight', 2),
#   ('Agility ~ Marksmanship', 2),
#   ('Agility ~ Longevity', 2),
#   ('Agility ~ Super Strength', 2)],
#  'Gorilla': [('Agility ~ Durability', 1),
#   ('Agility ~ Animal Attributes', 1),
#   ('Agility ~ Intelligence', 1),
#   ('Agility ~ Super Strength', 1),
#   ('Agility ~ Telepathy', 1)],
#  'Rodian': [],
#  'Flora Colossus': [('Durability ~ Longevity', 1),
#   ('Durability ~ Intelligence', 1),
#   ('Durability ~ Super Strength', 1),
#   ('Durability ~ Duplication', 1),
#   ('Durability ~ Size Changing', 1)],
#  'Human-Vuldarian': [('Lantern Power Ring ~ Durability', 1),
#   ('Lantern Power Ring ~ Flight', 1),
#   ('Lantern Power Ring ~ Marksmanship', 1),
#   ('Lantern Power Ring ~ Super Strength', 1),
#   ('Lantern Power Ring ~ Energy Blasts', 1)],
#  'Asgardian': [('Durability ~ Super Strength', 5),
#   ('Durability ~ Stamina', 5),
#   ('Super Strength ~ Stamina', 5),
#   ('Accelerated Healing ~ Durability', 4),
#   ('Accelerated Healing ~ Longevity', 4)],
#  'Demi-God': [('Durability ~ Longevity', 2),
#   ('Durability ~ Super Strength', 2),
#   ('Durability ~ Super Speed', 2),
#   ('Durability ~ Invulnerability', 2),
#   ('Longevity ~ Super Strength', 2)],
#  'Eternal': [('Agility ~ Durability', 2),
#   ('Agility ~ Flight', 2),
#   ('Agility ~ Longevity', 2),
#   ('Agility ~ Intelligence', 2),
#   ('Agility ~ Super Strength', 2)],
#  'Gungan': [('Agility ~ Stealth', 1),
#   ('Agility ~ Enhanced Smell', 1),
#   ('Agility ~ Sub-Mariner', 1),
#   ('Stealth ~ Enhanced Smell', 1),
#   ('Stealth ~ Sub-Mariner', 1)],
#  'Bolovaxian': [('Accelerated Healing ~ Lantern Power Ring', 1),
#   ('Accelerated Healing ~ Durability', 1),
#   ('Accelerated Healing ~ Underwater breathing', 1),
#   ('Accelerated Healing ~ Super Strength', 1),
#   ('Accelerated Healing ~ Telepathy', 1)],
#  'Animal': [('Cold Resistance ~ Animal Attributes', 2),
#   ('Cold Resistance ~ Animal Oriented Powers', 2),
#   ('Cold Resistance ~ Enhanced Smell', 2),
#   ('Animal Attributes ~ Animal Oriented Powers', 2),
#   ('Animal Attributes ~ Enhanced Smell', 2)],
#  'Czarnian': [('Durability ~ Longevity', 1),
#   ('Durability ~ Intelligence', 1),
#   ('Durability ~ Super Strength', 1),
#   ('Durability ~ Duplication', 1),
#   ('Durability ~ Stamina', 1)],
#  'Martian': [('Agility ~ Durability', 1),
#   ('Agility ~ Stealth', 1),
#   ('Agility ~ Flight', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Intelligence', 1)],
#  'Spartoi': [('Weapons Master ~ Intelligence', 1)],
#  'Luphomoid': [('Durability ~ Marksmanship', 1),
#   ('Durability ~ Super Strength', 1),
#   ('Marksmanship ~ Super Strength', 1)],
#  'Parademon': [('Flight ~ Super Strength', 1),
#   ('Flight ~ Shapeshifting', 1),
#   ('Flight ~ Fire Resistance', 1),
#   ('Flight ~ Heat Generation', 1),
#   ('Flight ~ Gliding', 1)],
#  'Yautja': [('Accelerated Healing ~ Cold Resistance', 1),
#   ('Accelerated Healing ~ Durability', 1),
#   ('Accelerated Healing ~ Stealth', 1),
#   ('Accelerated Healing ~ Marksmanship', 1),
#   ('Accelerated Healing ~ Weapons Master', 1)],
#  'Maiar': [('Accelerated Healing ~ Weapons Master', 1),
#   ('Accelerated Healing ~ Longevity', 1),
#   ('Accelerated Healing ~ Intelligence', 1),
#   ('Accelerated Healing ~ Super Strength', 1),
#   ('Accelerated Healing ~ Energy Blasts', 1)],
#  'Clone': [('Agility ~ Accelerated Healing', 1),
#   ('Agility ~ Durability', 1),
#   ('Agility ~ Animal Attributes', 1),
#   ('Agility ~ Super Strength', 1),
#   ('Agility ~ Stamina', 1)],
#  'Talokite': [('Agility ~ Stealth', 1),
#   ('Agility ~ Flight', 1),
#   ('Agility ~ Intelligence', 1),
#   ('Agility ~ Super Speed', 1),
#   ('Agility ~ Darkforce Manipulation', 1)],
#  'Korugaran': [('Agility ~ Durability', 1),
#   ('Agility ~ Flight', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Super Strength', 1),
#   ('Agility ~ Energy Blasts', 1)],
#  'Zombie': [('Cold Resistance ~ Durability', 1),
#   ('Cold Resistance ~ Energy Absorption', 1),
#   ('Cold Resistance ~ Super Strength', 1),
#   ('Cold Resistance ~ Stamina', 1),
#   ('Cold Resistance ~ Invulnerability', 1)],
#  'Human-Vulcan': [('Stealth ~ Longevity', 1),
#   ('Stealth ~ Intelligence', 1),
#   ('Stealth ~ Super Strength', 1),
#   ('Stealth ~ Telepathy', 1),
#   ('Stealth ~ Stamina', 1)],
#  'Human-Spartoi': [('Agility ~ Durability', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Weapons Master', 1),
#   ('Agility ~ Longevity', 1),
#   ('Agility ~ Intelligence', 1)],
#  'Tamaranean': [('Durability ~ Energy Absorption', 1),
#   ('Durability ~ Flight', 1),
#   ('Durability ~ Super Strength', 1),
#   ('Durability ~ Energy Blasts', 1),
#   ('Durability ~ Invulnerability', 1)],
#  'Frost Giant': [('Durability ~ Longevity', 2),
#   ('Durability ~ Super Strength', 2),
#   ('Longevity ~ Super Strength', 2),
#   ('Durability ~ Stamina', 1),
#   ('Durability ~ Magic', 1)],
#  'Mutant / Clone': [('Agility ~ Accelerated Healing', 1),
#   ('Agility ~ Durability', 1),
#   ('Agility ~ Stealth', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Longevity', 1)],
#  "Yoda's species": [('Agility ~ Stealth', 1),
#   ('Agility ~ Danger Sense', 1),
#   ('Agility ~ Marksmanship', 1),
#   ('Agility ~ Weapons Master', 1),
#   ('Agility ~ Longevity', 1)]}

# %%
#find the six most common races

race_list = heroes_and_powers_df['Race'].value_counts()[:6].index.tolist()
race_list
# Out:
# ['Unspecified',
#  'Human',
#  'Mutant',
#  'God / Eternal',
#  'Human / Radiation',
#  'Cyborg']

# %%
# make dict of 5 top cocurrences for 6 most common races
top_cocur_race = {k:v for k,v in top_dict.items() if k in race_list}
top_cocur_race
# Out:
# {'Human': [('Agility ~ Stamina', 73),
#   ('Super Strength ~ Super Speed', 60),
#   ('Agility ~ Super Strength', 58),
#   ('Stamina ~ Reflexes', 57),
#   ('Super Strength ~ Stamina', 54)],
#  'Human / Radiation': [('Super Strength ~ Stamina', 6),
#   ('Durability ~ Super Strength', 6),
#   ('Super Strength ~ Super Speed', 5),
#   ('Durability ~ Stamina', 5),
#   ('Accelerated Healing ~ Super Strength', 4)],
#  'Unspecified': [('Durability ~ Super Strength', 62),
#   ('Super Strength ~ Super Speed', 56),
#   ('Super Strength ~ Stamina', 50),
#   ('Flight ~ Super Strength', 45),
#   ('Stamina ~ Super Speed', 35)],
#  'Cyborg': [('Durability ~ Super Strength', 7),
#   ('Durability ~ Stamina', 7),
#   ('Super Strength ~ Stamina', 7),
#   ('Super Strength ~ Super Speed', 6),
#   ('Durability ~ Super Speed', 6)],
#  'Mutant': [('Agility ~ Stamina', 21),
#   ('Super Strength ~ Stamina', 20),
#   ('Accelerated Healing ~ Stamina', 20),
#   ('Agility ~ Accelerated Healing', 18),
#   ('Durability ~ Super Strength', 17)],
#  'God / Eternal': [('Super Strength ~ Immortality', 9),
#   ('Flight ~ Super Strength', 8),
#   ('Flight ~ Immortality', 8),
#   ('Intelligence ~ Immortality', 8),
#   ('Accelerated Healing ~ Teleportation', 7)]}

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15,25))

fig.suptitle('Graphs of most common superhero races and their most common cocurrent powers', y=1)

 

for n in range(6):
    r=race_list[n]
    x = [y[0] for y in top_cocur_race[r]]
    height = [z[1] for z in top_cocur_race[r]]
    row = n//2
    col = n%2
    ax = axes[row][col]

 

    ax.bar(x,height)
    ax.set_title(r)
    ax.set_ylabel("Number of occurences")
    ax.set_xticklabels(x, rotation=45)
    ax.set_xlabel("concurrent power")
    fig.tight_layout()
# Out:
# <ipython-input-70-5494c05427a0>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=45)

# %%
#Worth keeping unsepcified as it still gives us an idea of what powers are
#common across all heroes.

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
